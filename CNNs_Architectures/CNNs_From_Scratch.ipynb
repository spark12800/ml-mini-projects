# %% [markdown]
# # Problem 1: CIFAR10 CNN: training using minibatch gradient descent algorithms
#
# ## 0. Set up

# %%
pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (2.32.3)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.14.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras-tuner) (4.13.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.6 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
pip install --upgrade visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (11.1.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (2.0.2)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Downloading visualkeras-0.1.4-py3-none-any.whl (17 kB)
# Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.4/997.4 kB 17.7 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.4

# %%
# Import necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import visualkeras

# Deep learning modules
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dropout, Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Activation, GlobalAveragePooling2D, SpatialDropout2D, AveragePooling2D
from tensorflow.keras import Input, regularizers, layers
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, LearningRateScheduler, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import TopKCategoricalAccuracy
from tensorflow.keras.utils import plot_model

# Data preprocessing
from keras.utils import to_categorical

# Hyperparameters tuning modules
import kerastuner as kt
from keras_tuner import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
# Out:
# <ipython-input-3-d8ad12815fc8>:23: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   import kerastuner as kt

# %% [markdown]
# ## 1. Data loading and preprocessing

# %%
# Load the dataset and split into training/testing features and labels
from keras.datasets import cifar10
(data_train, label_train), (data_test, label_test) = cifar10.load_data()

# Data normalization
data_train, data_test = data_train / 255.0, data_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
data_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# One-hot encoding for labels (As I am using Categorical Crossentropy for loss function, instead of Sparse)
label_train = to_categorical(label_train, 10)
label_test = to_categorical(label_test, 10)
label_test.shape[-1]
# Out:
# 10

# %% [markdown]
# ## 2. Set hyperparameters
#
# **Set hyperparameters as followed:**
# *   batch_size = 128
# *   learning_rate = 0.001
# *   epoches = 100
# *   dropout = [0.1, 0.3, 0.5, 0.7]

# %%
# Define some hyperparameters for model definition
batch_size = 128
learning_rate = 0.001
n_epoch = 100
dropout = [a for a in np.arange(0.1, 1, 0.2)]

# %%
# For plotting purposes
optimizer_names = ['GD','Adagrad','RMSprop','Nesterov','Adam']

# Methods to be tested along with any specific parameter
optimizer_list = [keras.optimizers.SGD(learning_rate=learning_rate), 'Adagrad', 'RMSprop', keras.optimizers.SGD(learning_rate=learning_rate, nesterov=True),'Adam']

# %%
n_features = data_train.shape[1:]

n_classes = label_train.shape[-1]

# %% [markdown]
# ##3. Building Convolutional Neural Network (CNN) models
#
# Here, I first implement a CNN architecture that consists of 3 convolutional layers followed by a fully connected layer of 1000 units, under the conditions below:
#
# 3x32x32-32C5-P2-64C5-P2-128C5-P2-1000N-10N
#
# *  Convolutional Filters Size : 5x5
# *  Convolutional Stride : (1, 1)
# *  Max-Pool Size : 2x2
# *  Max-Pool Stride : (2, 2)
# *  Activation Function : ReLU

# %% [markdown]
# ###Step 1: Compare Optimization Algorithms
#
#
# ---
#
#
# * Mini-batch gradient descent
# * Mini-batch AdaGrad
# * Mini-batch RMSProp
# * Mini-batch gradient descent with Nesterov’s momentum
# * Mini-batch Adam
#
# First, to compare optimization techniques, **I first applied dropout only at the end of the fully connected layers, using a dropout rate of 0.3.** This decisi convolutional layers already contain significantly fewer trainable parameters. In CNNs, the convolutional filter operates uniformly across every region of the image (translation equivariance), and each kernel focuses on local pixel regions (locality principle). This shared-filter architecture reduces both the number of parameters and the risk of overfitting, making additional weight removal through dropout less desirable.
#
# Additionally, to obtain the average training loss per epoch versus the number of epochs for the training dataset, I set **steps_per_epoch=50 and shuffle=True.**

# %%
def build_compile(optimizer_list='GD'):
    model_base = Sequential()

    # First Convoluntional layer
    model_base.add(Conv2D(36, (5,5), input_shape=n_features, padding='same', activation='relu')) # default for stride as (1, 1)
    model_base.add(MaxPooling2D(strides=(2, 2))) # default for pool_size and padding as "valid"

    # Second Convoluntional layer
    model_base.add(Conv2D(64, (5,5), padding='same', activation='relu'))
    model_base.add(MaxPooling2D(strides=(2, 2)))

    # Third Convoluntional layer
    model_base.add(Conv2D(128, (5,5), padding='same', activation='relu'))
    model_base.add(MaxPooling2D(strides=(2, 2)))

    # Fully Connected layer
    model_base.add(Flatten())
    model_base.add(Dropout(.3))
    model_base.add(Dense(1000, activation='relu'))
    model_base.add(Dense(n_classes, activation='softmax'))

    # Compile the model with a cross-entropy loss and specify the given optimiser
    model_base.compile(optimizer=optimizer_list, loss=keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])
    model_base.summary()

    return model_base

# %%
# Two arrays for training and validation performance
hist_loss_nn = []

start = time.time()

# Iterate over optimizers and train the network
for item, name in zip(optimizer_list, optimizer_names):
    print("-----------------------------")
    print("Doing %s optimizer" %str(name))
    print("-----------------------------")

    # Get the model from our function above
    model = build_compile(optimizer_list=item)

    # Train the model
    history = model.fit(data_train, label_train, epochs=n_epoch, batch_size=batch_size, steps_per_epoch=50, shuffle=True)

    # Store the performance
    hist_loss_nn.append(history.history['loss'])
    print("-----------------------------")

end = time.time()
time_nn = (end-start) / 60
print('minutes to run: ', time_nn)
# Out:
# -----------------------------
# Doing GD optimizer
# -----------------------------
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 36)          │           2,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 36)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 64)          │          57,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1000)                │       2,049,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │          10,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,324,338 (8.87 MB)
#  Trainable params: 2,324,338 (8.87 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.1024 - loss: 2.3070
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1129 - loss: 2.3025
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1081 - loss: 2.3017
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1234 - loss: 2.2979
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1214 - loss: 2.2997
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1261 - loss: 2.2970
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1373 - loss: 2.2954
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.1351 - loss: 2.2963
# Epoch 9/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1307 - loss: 2.2954
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1309 - loss: 2.2940
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1207 - loss: 2.2954
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1382 - loss: 2.2917
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1396 - loss: 2.2900
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1330 - loss: 2.2918
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1268 - loss: 2.2907
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1327 - loss: 2.2879
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1391 - loss: 2.2881
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1454 - loss: 2.2862
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1406 - loss: 2.2870
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1326 - loss: 2.2853
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1429 - loss: 2.2826
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1424 - loss: 2.2850
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1489 - loss: 2.2810
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1563 - loss: 2.2777
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1522 - loss: 2.2771
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1528 - loss: 2.2789
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1565 - loss: 2.2796
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1622 - loss: 2.2752
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1559 - loss: 2.2748
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1686 - loss: 2.2693
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1555 - loss: 2.2725
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1634 - loss: 2.2712
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1636 - loss: 2.2677
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1558 - loss: 2.2680
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1584 - loss: 2.2631
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1632 - loss: 2.2634
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1784 - loss: 2.2595
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1694 - loss: 2.2586
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1739 - loss: 2.2570
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1864 - loss: 2.2524
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1900 - loss: 2.2534
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1860 - loss: 2.2492
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1877 - loss: 2.2460
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1759 - loss: 2.2412
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1839 - loss: 2.2414
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1760 - loss: 2.2476
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1910 - loss: 2.2314
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1792 - loss: 2.2350
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1723 - loss: 2.2328
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2099 - loss: 2.2153
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2016 - loss: 2.2193
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1939 - loss: 2.2142
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1980 - loss: 2.2148
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1849 - loss: 2.2198
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1917 - loss: 2.2092
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2050 - loss: 2.1983
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1869 - loss: 2.2026
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2058 - loss: 2.1933
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2063 - loss: 2.1860
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1908 - loss: 2.1884
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1987 - loss: 2.1878
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2100 - loss: 2.1657
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2094 - loss: 2.1666
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2233 - loss: 2.1657
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2095 - loss: 2.1664
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2124 - loss: 2.1682
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2187 - loss: 2.1486
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2339 - loss: 2.1436
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2415 - loss: 2.1249
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2279 - loss: 2.1198
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2225 - loss: 2.1207
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2414 - loss: 2.1039
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2425 - loss: 2.1103
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2416 - loss: 2.1130
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2481 - loss: 2.0771
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2497 - loss: 2.0884
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2450 - loss: 2.0859
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2452 - loss: 2.0754
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2514 - loss: 2.0705
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2622 - loss: 2.0560
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2566 - loss: 2.0575
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2567 - loss: 2.0528
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2568 - loss: 2.0436
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2608 - loss: 2.0347
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2631 - loss: 2.0325
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2755 - loss: 2.0114
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2804 - loss: 2.0046
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2754 - loss: 2.0055
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2747 - loss: 2.0110
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2811 - loss: 1.9911
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2776 - loss: 2.0014
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2758 - loss: 2.0030
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2904 - loss: 1.9980
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2833 - loss: 1.9875
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2855 - loss: 1.9851
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2791 - loss: 1.9912
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2847 - loss: 1.9708
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2868 - loss: 1.9726
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2849 - loss: 1.9778
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2954 - loss: 1.9709
# -----------------------------
# -----------------------------
# Doing Adagrad optimizer
# -----------------------------
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 36)          │           2,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 16, 16, 36)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 16, 16, 64)          │          57,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1000)                │       2,049,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │          10,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,324,338 (8.87 MB)
#  Trainable params: 2,324,338 (8.87 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1006 - loss: 2.3077
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1066 - loss: 2.3016
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1113 - loss: 2.2975
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1333 - loss: 2.2907
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1405 - loss: 2.2869
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1540 - loss: 2.2838
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1631 - loss: 2.2805
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.1718 - loss: 2.2708
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1784 - loss: 2.2624
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1745 - loss: 2.2590
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1856 - loss: 2.2472
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1789 - loss: 2.2396
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1950 - loss: 2.2164
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2183 - loss: 2.1991
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1975 - loss: 2.1829
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2315 - loss: 2.1477
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2341 - loss: 2.1276
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2242 - loss: 2.1139
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2329 - loss: 2.0859
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2494 - loss: 2.0563
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2562 - loss: 2.0489
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2616 - loss: 2.0253
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2468 - loss: 2.0364
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2668 - loss: 2.0119
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2723 - loss: 2.0120
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2736 - loss: 1.9950
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2686 - loss: 2.0019
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2776 - loss: 1.9850
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2780 - loss: 1.9832
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2962 - loss: 1.9623
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2963 - loss: 1.9428
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2974 - loss: 1.9602
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3047 - loss: 1.9363
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3004 - loss: 1.9429
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3073 - loss: 1.9290
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3176 - loss: 1.9275
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2942 - loss: 1.9430
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3049 - loss: 1.9230
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3197 - loss: 1.9072
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3224 - loss: 1.9023
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3277 - loss: 1.9084
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3136 - loss: 1.9053
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3206 - loss: 1.8845
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3173 - loss: 1.9033
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3374 - loss: 1.8627
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3475 - loss: 1.8721
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3405 - loss: 1.8633
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3455 - loss: 1.8562
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3550 - loss: 1.8321
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3499 - loss: 1.8298
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3543 - loss: 1.8261
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3516 - loss: 1.8386
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3482 - loss: 1.8094
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3458 - loss: 1.8285
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3446 - loss: 1.8022
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3521 - loss: 1.8253
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3604 - loss: 1.8119
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3677 - loss: 1.7959
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3696 - loss: 1.7789
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3584 - loss: 1.7834
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3729 - loss: 1.7634
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3647 - loss: 1.7525
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3715 - loss: 1.7588
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3744 - loss: 1.7677
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3627 - loss: 1.7540
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3809 - loss: 1.7508
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3904 - loss: 1.7016
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3673 - loss: 1.7497
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3785 - loss: 1.7387
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3702 - loss: 1.7467
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3784 - loss: 1.7414
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3959 - loss: 1.7056
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.3823 - loss: 1.7347
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3816 - loss: 1.7097
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3735 - loss: 1.7401
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3913 - loss: 1.7038
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3835 - loss: 1.7052
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4001 - loss: 1.6997
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3925 - loss: 1.7004
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3979 - loss: 1.7131
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3975 - loss: 1.6945
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4125 - loss: 1.6528
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4017 - loss: 1.6870
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3961 - loss: 1.6893
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3957 - loss: 1.6665
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3930 - loss: 1.7022
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4043 - loss: 1.6599
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3930 - loss: 1.6659
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4107 - loss: 1.6459
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3997 - loss: 1.6650
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4084 - loss: 1.6680
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4090 - loss: 1.6412
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4084 - loss: 1.6480
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4239 - loss: 1.6450
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4200 - loss: 1.6161
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4150 - loss: 1.6485
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4075 - loss: 1.6602
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4261 - loss: 1.6176
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4232 - loss: 1.6248
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4231 - loss: 1.6160
# -----------------------------
# -----------------------------
# Doing RMSprop optimizer
# -----------------------------
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 32, 32, 36)          │           2,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 16, 16, 36)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 16, 16, 64)          │          57,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 8, 8, 128)           │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1000)                │       2,049,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │          10,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,324,338 (8.87 MB)
#  Trainable params: 2,324,338 (8.87 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1170 - loss: 2.3405
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1976 - loss: 2.1597
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2793 - loss: 1.9745
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3356 - loss: 1.8079
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3824 - loss: 1.6855
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4232 - loss: 1.5874
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4441 - loss: 1.5479
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.4609 - loss: 1.5059
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4850 - loss: 1.4341
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4922 - loss: 1.4020
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4972 - loss: 1.3917
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5281 - loss: 1.3231
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5388 - loss: 1.3056
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5581 - loss: 1.2635
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5733 - loss: 1.1913
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5883 - loss: 1.1716
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6099 - loss: 1.0939
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6113 - loss: 1.0772
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6317 - loss: 1.0456
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6273 - loss: 1.0764
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6208 - loss: 1.0797
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6131 - loss: 1.0726
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6349 - loss: 1.0354
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6399 - loss: 1.0383
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6698 - loss: 0.9346
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6824 - loss: 0.9206
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6884 - loss: 0.8933
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6912 - loss: 0.8681
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6900 - loss: 0.9040
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6899 - loss: 0.9012
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6889 - loss: 0.8699
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6936 - loss: 0.8749
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7222 - loss: 0.7925
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7129 - loss: 0.8111
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7363 - loss: 0.7694
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7109 - loss: 0.8213
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7379 - loss: 0.7505
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7405 - loss: 0.7624
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7252 - loss: 0.7896
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7124 - loss: 0.8056
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7588 - loss: 0.6822
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7674 - loss: 0.6704
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7462 - loss: 0.7303
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7607 - loss: 0.6805
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7586 - loss: 0.7001
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7660 - loss: 0.6593
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7499 - loss: 0.6949
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7578 - loss: 0.6834
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8006 - loss: 0.5805
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7928 - loss: 0.5849
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7890 - loss: 0.6001
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7954 - loss: 0.5940
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7912 - loss: 0.5852
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7790 - loss: 0.6119
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7822 - loss: 0.6220
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7843 - loss: 0.6316
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8270 - loss: 0.5019
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8259 - loss: 0.4770
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8264 - loss: 0.5052
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8086 - loss: 0.5491
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8084 - loss: 0.5628
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8128 - loss: 0.5426
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8228 - loss: 0.5182
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8283 - loss: 0.5036
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8610 - loss: 0.3958
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8601 - loss: 0.4149
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8223 - loss: 0.4997
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8321 - loss: 0.4527
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8381 - loss: 0.4529
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8405 - loss: 0.4495
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8444 - loss: 0.4464
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8371 - loss: 0.4574
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8736 - loss: 0.3467
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8713 - loss: 0.3621
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8697 - loss: 0.3667
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8600 - loss: 0.3938
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8605 - loss: 0.3931
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8699 - loss: 0.3681
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8588 - loss: 0.3957
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8557 - loss: 0.4052
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8996 - loss: 0.2929
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8970 - loss: 0.3008
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8887 - loss: 0.3268
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8831 - loss: 0.3337
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8794 - loss: 0.3402
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8840 - loss: 0.3249
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8694 - loss: 0.3633
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8793 - loss: 0.3459
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9101 - loss: 0.2591
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9139 - loss: 0.2552
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9042 - loss: 0.2795
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8959 - loss: 0.2865
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8878 - loss: 0.3115
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8941 - loss: 0.2906
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8892 - loss: 0.3108
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8983 - loss: 0.2928
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9197 - loss: 0.2386
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9259 - loss: 0.2231
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9012 - loss: 0.2834
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9207 - loss: 0.2184
# -----------------------------
# -----------------------------
# Doing Nesterov optimizer
# -----------------------------
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)                    │ (None, 32, 32, 36)          │           2,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 16, 16, 36)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 16, 16, 64)          │          57,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 8, 8, 128)           │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1000)                │       2,049,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │          10,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,324,338 (8.87 MB)
#  Trainable params: 2,324,338 (8.87 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1042 - loss: 2.3031
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0939 - loss: 2.3014
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0991 - loss: 2.2990
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1077 - loss: 2.2958
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1073 - loss: 2.2949
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1074 - loss: 2.2969
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1093 - loss: 2.2921
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1097 - loss: 2.2910
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1074 - loss: 2.2936
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1176 - loss: 2.2890
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1308 - loss: 2.2840
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1203 - loss: 2.2839
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1225 - loss: 2.2826
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1243 - loss: 2.2848
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1333 - loss: 2.2786
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1364 - loss: 2.2793
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1265 - loss: 2.2777
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1285 - loss: 2.2778
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1393 - loss: 2.2705
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1415 - loss: 2.2728
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1433 - loss: 2.2709
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1432 - loss: 2.2668
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1431 - loss: 2.2673
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1484 - loss: 2.2617
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1587 - loss: 2.2573
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1495 - loss: 2.2599
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1607 - loss: 2.2586
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1667 - loss: 2.2522
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1604 - loss: 2.2534
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1812 - loss: 2.2438
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1627 - loss: 2.2433
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1767 - loss: 2.2379
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1668 - loss: 2.2342
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1714 - loss: 2.2348
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1908 - loss: 2.2175
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1829 - loss: 2.2193
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1822 - loss: 2.2212
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1886 - loss: 2.2160
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1875 - loss: 2.2061
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1967 - loss: 2.1969
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1952 - loss: 2.2021
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2022 - loss: 2.1935
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1942 - loss: 2.1836
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1943 - loss: 2.1812
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2081 - loss: 2.1736
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1957 - loss: 2.1780
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2108 - loss: 2.1681
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2214 - loss: 2.1346
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.2171 - loss: 2.1415
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2158 - loss: 2.1403
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2332 - loss: 2.1196
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2368 - loss: 2.1206
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2300 - loss: 2.1127
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2371 - loss: 2.0993
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2530 - loss: 2.0933
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2494 - loss: 2.0821
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2597 - loss: 2.0683
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2491 - loss: 2.0727
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2470 - loss: 2.0666
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2538 - loss: 2.0504
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2428 - loss: 2.0542
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2520 - loss: 2.0465
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2648 - loss: 2.0331
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2523 - loss: 2.0233
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2593 - loss: 2.0224
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2503 - loss: 2.0325
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2746 - loss: 2.0161
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2623 - loss: 2.0188
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2736 - loss: 2.0085
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2650 - loss: 2.0096
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2694 - loss: 2.0082
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2741 - loss: 2.0111
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2875 - loss: 1.9907
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2753 - loss: 1.9803
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2875 - loss: 1.9941
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2576 - loss: 1.9969
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2752 - loss: 1.9911
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2762 - loss: 1.9853
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2697 - loss: 1.9947
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2769 - loss: 1.9749
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2779 - loss: 1.9725
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2868 - loss: 1.9860
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2870 - loss: 1.9651
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2860 - loss: 1.9727
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2814 - loss: 1.9723
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3032 - loss: 1.9545
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2900 - loss: 1.9463
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3039 - loss: 1.9435
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2822 - loss: 1.9583
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2938 - loss: 1.9470
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2950 - loss: 1.9672
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2922 - loss: 1.9546
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2946 - loss: 1.9310
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3110 - loss: 1.9449
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3049 - loss: 1.9391
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2826 - loss: 1.9392
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3032 - loss: 1.9236
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3051 - loss: 1.9276
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3013 - loss: 1.9515
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2969 - loss: 1.9412
# -----------------------------
# -----------------------------
# Doing Adam optimizer
# -----------------------------
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 32, 32, 36)          │           2,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 16, 16, 36)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 16, 16, 64)          │          57,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 8, 8, 128)           │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1000)                │       2,049,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 10)                  │          10,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,324,338 (8.87 MB)
#  Trainable params: 2,324,338 (8.87 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1739 - loss: 2.1996
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3612 - loss: 1.7415
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4243 - loss: 1.5633
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4432 - loss: 1.5043
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4593 - loss: 1.4471
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5098 - loss: 1.3533
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5212 - loss: 1.3149
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.5532 - loss: 1.2527
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5858 - loss: 1.1897
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5813 - loss: 1.1595
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5983 - loss: 1.1247
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5991 - loss: 1.1304
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6084 - loss: 1.0968
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6014 - loss: 1.1066
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6141 - loss: 1.0806
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6306 - loss: 1.0620
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6455 - loss: 1.0001
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6516 - loss: 0.9773
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6500 - loss: 0.9833
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6829 - loss: 0.8936
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6596 - loss: 0.9517
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6727 - loss: 0.9053
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6760 - loss: 0.9184
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6757 - loss: 0.9180
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7030 - loss: 0.8457
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7083 - loss: 0.8218
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7136 - loss: 0.8186
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7209 - loss: 0.7957
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6950 - loss: 0.8555
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7167 - loss: 0.8021
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7138 - loss: 0.8089
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7106 - loss: 0.8261
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7582 - loss: 0.6876
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7461 - loss: 0.6956
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7583 - loss: 0.6903
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7427 - loss: 0.7292
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7345 - loss: 0.7599
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7439 - loss: 0.7145
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7605 - loss: 0.7018
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7471 - loss: 0.7055
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7858 - loss: 0.5946
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7755 - loss: 0.6488
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7801 - loss: 0.6222
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7753 - loss: 0.6266
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7627 - loss: 0.6687
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7780 - loss: 0.6082
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7845 - loss: 0.5909
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7534 - loss: 0.6733
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8053 - loss: 0.5301
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8035 - loss: 0.5445
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7878 - loss: 0.5822
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8127 - loss: 0.5532
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7928 - loss: 0.5789
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7990 - loss: 0.5959
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7928 - loss: 0.5706
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7927 - loss: 0.6119
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8176 - loss: 0.5033
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8403 - loss: 0.4550
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8439 - loss: 0.4626
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8284 - loss: 0.4936
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8248 - loss: 0.5002
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8347 - loss: 0.4743
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8165 - loss: 0.5224
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8319 - loss: 0.4804
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8629 - loss: 0.3883
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8578 - loss: 0.3958
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8619 - loss: 0.4136
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8474 - loss: 0.4166
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8415 - loss: 0.4399
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8471 - loss: 0.4212
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8336 - loss: 0.4544
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8536 - loss: 0.4082
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8857 - loss: 0.3385
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8850 - loss: 0.3210
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8718 - loss: 0.3562
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8779 - loss: 0.3509
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8513 - loss: 0.4108
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8621 - loss: 0.3844
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8673 - loss: 0.3712
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8632 - loss: 0.3926
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9103 - loss: 0.2591
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8997 - loss: 0.2711
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8845 - loss: 0.3162
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8687 - loss: 0.3388
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8899 - loss: 0.3068
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8863 - loss: 0.3208
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8820 - loss: 0.3209
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8711 - loss: 0.3522
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9230 - loss: 0.2246
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9048 - loss: 0.2637
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8935 - loss: 0.2944
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9110 - loss: 0.2521
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9101 - loss: 0.2525
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8907 - loss: 0.2973
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8947 - loss: 0.3003
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9083 - loss: 0.2719
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9316 - loss: 0.1978
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9224 - loss: 0.2198
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9216 - loss: 0.2250
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9157 - loss: 0.2419
# -----------------------------
# minutes to run:  5.232011377811432

# %%
for i in range(len(optimizer_list)):
    plt.plot(hist_loss_nn[i],label=str(optimizer_names[i]))
plt.title('Average Loss on Training Set')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')

# %% [markdown]
# Based on the basic CNN architecture (3×32×32 → 32C5 → P2 → 64C5 → P2 → 128C5 → P2 → 1000N → 10N), **Adam optimiser consistently outperforms others**, followed by RMSProp, Adagrad, Nesterov, and batch-normalised gradient descent. This may be because Adam combines the benefits of momentum and adaptive learning rates, allowing faster convergence, while Nesterov’s accelerated gradient anticipates future parameter updates, leading to more informed steps. However, it is important to note that the effectiveness of an optimiser can depend significantly on model architecture and hyperparameter settings, so one should avoid overgeneralising from these outcomes.
#
# For instance, Choi et al. (2019) demonstrated that, with additional tuning of optimisation hyperparameters and weight decay, SGD, Momentum, RMSProp, and Adam achieved nearly identical test error rates. This suggests that while certain optimisers may show better performance under default settings, their effectiveness can shift with proper tuning.
#
# Nevertheless, due to limited computational resources, I did not conduct extensive hyperparameter tuning across different optimisers in this experiment.

# %% [markdown]
# ###Step 2: Add Dropout at Different Layers & Different Rates
#
#
#
# ---
# With Adam, I will use dropout in the same CNN architecture, adjusting the probability of each unit being dropped in the network. I will also apply dropout to different layers, and compare to identify which one is outperforming. In particular, adding dropout to the max-pooling layer may make the pooling process more stochastic, rather than always selecting the strongest feature. This may potentially mitigate overfitting to dominant features.
#
# Here, dropout will be applied **after convolutional layers**, **pooling layers**, and **fully connected layers**. Dropout rate of **0.1**, **0.3**, **0.5**, **0.7**, **0.9** for each layer will be tested.

# %%
# Tune Dropout for Convolutional Layers
def build_dropout_model_conv(hp):
    model_drop_conv = Sequential()
    model_drop_conv.add(Conv2D(32, (5, 5), activation='relu', padding='same', input_shape=n_features))
    model_drop_conv.add(SpatialDropout2D(hp.Choice('dropout_conv', dropout)))
    model_drop_conv.add(MaxPooling2D(strides=(2, 2)))

    model_drop_conv.add(Conv2D(64, (5, 5), activation='relu', padding='same'))
    model_drop_conv.add(SpatialDropout2D(hp.Choice('dropout_conv', dropout)))
    model_drop_conv.add(MaxPooling2D(strides=(2, 2)))

    model_drop_conv.add(Conv2D(128, (5, 5), activation='relu', padding='same'))
    model_drop_conv.add(SpatialDropout2D(hp.Choice('dropout_conv', dropout)))
    model_drop_conv.add(MaxPooling2D(strides=(2, 2)))

    model_drop_conv.add(Flatten())
    model_drop_conv.add(Dense(1000, activation='relu'))
    model_drop_conv.add(Dense(n_classes, activation='softmax'))

    model_drop_conv.compile(optimizer='Adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])
    return model_drop_conv


# Tune Dropout for Pooling Layers
def build_dropout_model_pool(hp):
    model_drop_pool = Sequential()
    model_drop_pool.add(Conv2D(32, (5, 5), activation='relu', padding='same', input_shape=n_features))
    model_drop_pool.add(MaxPooling2D(strides=(2, 2)))
    model_drop_pool.add(Dropout(hp.Choice('dropout_pool', dropout)))

    model_drop_pool.add(Conv2D(64, (5, 5), activation='relu', padding='same'))
    model_drop_pool.add(MaxPooling2D(strides=(2, 2)))
    model_drop_pool.add(Dropout(hp.Choice('dropout_pool', dropout)))

    model_drop_pool.add(Conv2D(128, (5, 5), activation='relu', padding='same'))
    model_drop_pool.add(MaxPooling2D(strides=(2, 2)))
    model_drop_pool.add(Dropout(hp.Choice('dropout_pool', dropout)))

    model_drop_pool.add(Flatten())
    model_drop_pool.add(Dense(1000, activation='relu'))
    model_drop_pool.add(Dense(n_classes, activation='softmax'))

    model_drop_pool.compile(optimizer='Adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])
    return model_drop_pool


# Tune Dropout for Fully Connected (FC) Layers
def build_dropout_model_fc(hp):
    model_drop_fc = Sequential()
    model_drop_fc.add(Conv2D(32, (5, 5), activation='relu', padding='same', input_shape=n_features))
    model_drop_fc.add(MaxPooling2D(strides=(2, 2)))

    model_drop_fc.add(Conv2D(64, (5, 5), activation='relu', padding='same'))
    model_drop_fc.add(MaxPooling2D(strides=(2, 2)))

    model_drop_fc.add(Conv2D(128, (5, 5), activation='relu', padding='same'))
    model_drop_fc.add(MaxPooling2D(strides=(2, 2)))

    model_drop_fc.add(Flatten())
    model_drop_fc.add(Dense(1000, activation='relu'))
    model_drop_fc.add(Dropout(hp.Choice('dropout_fc', dropout)))
    model_drop_fc.add(Dense(n_classes, activation='softmax'))

    model_drop_fc.compile(optimizer='Adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])
    return model_drop_fc

# %%
# Tuning Dropout in Convolutional Layers
tuner_conv = kt.Hyperband(build_dropout_model_conv, objective='val_accuracy', max_epochs=60, factor=3, directory='store_drop_1', project_name='conv1_drop_1')

# Tuning Dropout in Pooling Layers
tuner_pool = kt.Hyperband(build_dropout_model_pool, objective='val_accuracy', max_epochs=60, factor=3, directory='store_drop_1', project_name='pool2_drop_2')

# Tuning Dropout in Fully Connected Layers
tuner_fc = kt.Hyperband(build_dropout_model_fc, objective='val_accuracy', max_epochs=60, factor=3, directory='store_drop_1', project_name='fc1_drop_1')

# Hyperparameter search for each
tuner_conv.search(data_train, label_train, epochs=70, validation_split=0.2, verbose=1)
tuner_pool.search(data_train, label_train, epochs=70, validation_split=0.2, verbose=1)
tuner_fc.search(data_train, label_train, epochs=70, validation_split=0.2, verbose=1)
# Out:
# Trial 5 Complete [00h 00m 30s]
# val_accuracy: 0.6632999777793884
#
# Best val_accuracy So Far: 0.680899977684021
# Total elapsed time: 00h 02m 42s

# %%
# Best dropout rates from KerasTuner
best_hps_conv = tuner_conv.get_best_hyperparameters(num_trials=1)[0]
best_hps_pool = tuner_pool.get_best_hyperparameters(num_trials=1)[0]
best_hps_fc = tuner_fc.get_best_hyperparameters(num_trials=1)[0]

# Store best dropout rates
best_dropout_conv = best_hps_conv.get('dropout_conv')
best_dropout_pool = best_hps_pool.get('dropout_pool')
best_dropout_fc = best_hps_fc.get('dropout_fc')

print("Best Dropout Rate for Convolutional Layers:", best_dropout_conv)
print("Best Dropout Rate for Pooling Layers:", best_dropout_pool)
print("Best Dropout Rate for Fully Connected Layers:", best_dropout_fc)
# Out:
# Best Dropout Rate for Convolutional Layers: 0.1
# Best Dropout Rate for Pooling Layers: 0.1
# Best Dropout Rate for Fully Connected Layers: 0.30000000000000004

# %%
# Store training histories
histories = {}

# Train model using best convolutional dropout
print("\nTraining Model with Best Conv Dropout...")
best_model_conv = build_dropout_model_conv(kt.HyperParameters())
best_model_conv.get_layer(index=1).rate = best_dropout_conv
history_conv = best_model_conv.fit(data_train, label_train, epochs=n_epoch, batch_size=batch_size, validation_split=0.2, steps_per_epoch=50, shuffle=True)
histories["Conv Dropout"] = history_conv

# Train model using best pooling dropout
print("\nTraining Model with Best Pool Dropout...")
best_model_pool = build_dropout_model_pool(kt.HyperParameters())
best_model_pool.get_layer(index=3).rate = best_dropout_pool
history_pool = best_model_pool.fit(data_train, label_train, epochs=n_epoch, batch_size=batch_size, validation_split=0.2, steps_per_epoch=50, shuffle=True)
histories["Pool Dropout"] = history_pool

# Train model using best fully connected dropout
print("\nTraining Model with Best FC Dropout...")
best_model_fc = build_dropout_model_fc(kt.HyperParameters())
best_model_fc.get_layer(index=6).rate = best_dropout_fc
history_fc = best_model_fc.fit(data_train, label_train, epochs=n_epoch, batch_size=batch_size, validation_split=0.2, steps_per_epoch=50, shuffle=True)
histories["FC Dropout"] = history_fc
# Out:
# Training Model with Best Conv Dropout...
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.1647 - loss: 2.2021 - val_accuracy: 0.3213 - val_loss: 1.8429
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3298 - loss: 1.8117 - val_accuracy: 0.3903 - val_loss: 1.6485
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4135 - loss: 1.6303 - val_accuracy: 0.4719 - val_loss: 1.4646
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4627 - loss: 1.5063 - val_accuracy: 0.4899 - val_loss: 1.3905
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4947 - loss: 1.4175 - val_accuracy: 0.5291 - val_loss: 1.3345
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5165 - loss: 1.3502 - val_accuracy: 0.5511 - val_loss: 1.2404
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.5240 - loss: 1.3153 - val_accuracy: 0.5525 - val_loss: 1.2408
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.5459 - loss: 1.2581 - val_accuracy: 0.5655 - val_loss: 1.2299
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5679 - loss: 1.2099 - val_accuracy: 0.5854 - val_loss: 1.1709
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5768 - loss: 1.1880 - val_accuracy: 0.6222 - val_loss: 1.0880
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5794 - loss: 1.1703 - val_accuracy: 0.6119 - val_loss: 1.0883
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5988 - loss: 1.1402 - val_accuracy: 0.6198 - val_loss: 1.0811
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5869 - loss: 1.1342 - val_accuracy: 0.6289 - val_loss: 1.0554
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6126 - loss: 1.0727 - val_accuracy: 0.6301 - val_loss: 1.0340
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6277 - loss: 1.0465 - val_accuracy: 0.6556 - val_loss: 0.9867
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6338 - loss: 1.0170 - val_accuracy: 0.6526 - val_loss: 0.9921
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6511 - loss: 0.9910 - val_accuracy: 0.6622 - val_loss: 0.9684
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6612 - loss: 0.9542 - val_accuracy: 0.6707 - val_loss: 0.9345
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6645 - loss: 0.9396 - val_accuracy: 0.6670 - val_loss: 0.9452
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6739 - loss: 0.9322 - val_accuracy: 0.6813 - val_loss: 0.9133
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6806 - loss: 0.9270 - val_accuracy: 0.6749 - val_loss: 0.9286
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6890 - loss: 0.8749 - val_accuracy: 0.6710 - val_loss: 0.9588
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6971 - loss: 0.8663 - val_accuracy: 0.6795 - val_loss: 0.9138
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6970 - loss: 0.8579 - val_accuracy: 0.6811 - val_loss: 0.9231
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6952 - loss: 0.8841 - val_accuracy: 0.6926 - val_loss: 0.8824
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6829 - loss: 0.8796 - val_accuracy: 0.7066 - val_loss: 0.8470
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6996 - loss: 0.8636 - val_accuracy: 0.6994 - val_loss: 0.8629
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7123 - loss: 0.8300 - val_accuracy: 0.7045 - val_loss: 0.8523
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7347 - loss: 0.7435 - val_accuracy: 0.7149 - val_loss: 0.8278
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7321 - loss: 0.7529 - val_accuracy: 0.7067 - val_loss: 0.8639
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7038 - loss: 0.8215 - val_accuracy: 0.7086 - val_loss: 0.8294
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7494 - loss: 0.7324 - val_accuracy: 0.7135 - val_loss: 0.8121
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7372 - loss: 0.7621 - val_accuracy: 0.7090 - val_loss: 0.8299
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7389 - loss: 0.7501 - val_accuracy: 0.7097 - val_loss: 0.8245
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7301 - loss: 0.7566 - val_accuracy: 0.7214 - val_loss: 0.8065
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7726 - loss: 0.6550 - val_accuracy: 0.7187 - val_loss: 0.8154
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7681 - loss: 0.6518 - val_accuracy: 0.7227 - val_loss: 0.8053
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7768 - loss: 0.6456 - val_accuracy: 0.7187 - val_loss: 0.8178
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7623 - loss: 0.6712 - val_accuracy: 0.7150 - val_loss: 0.8150
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7740 - loss: 0.6582 - val_accuracy: 0.7220 - val_loss: 0.7941
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7687 - loss: 0.6576 - val_accuracy: 0.7246 - val_loss: 0.7974
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7629 - loss: 0.6341 - val_accuracy: 0.7240 - val_loss: 0.8018
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8029 - loss: 0.5538 - val_accuracy: 0.7301 - val_loss: 0.8101
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8018 - loss: 0.5698 - val_accuracy: 0.7257 - val_loss: 0.8036
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8000 - loss: 0.5591 - val_accuracy: 0.7325 - val_loss: 0.7897
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7901 - loss: 0.5913 - val_accuracy: 0.7319 - val_loss: 0.7816
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7807 - loss: 0.5976 - val_accuracy: 0.7250 - val_loss: 0.8046
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7882 - loss: 0.5975 - val_accuracy: 0.7316 - val_loss: 0.7984
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7915 - loss: 0.5923 - val_accuracy: 0.7346 - val_loss: 0.7868
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8201 - loss: 0.4879 - val_accuracy: 0.7305 - val_loss: 0.8129
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8376 - loss: 0.4616 - val_accuracy: 0.7320 - val_loss: 0.8170
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8178 - loss: 0.5141 - val_accuracy: 0.7357 - val_loss: 0.7992
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8224 - loss: 0.4958 - val_accuracy: 0.7314 - val_loss: 0.8278
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8105 - loss: 0.5209 - val_accuracy: 0.7368 - val_loss: 0.7924
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8120 - loss: 0.5342 - val_accuracy: 0.7275 - val_loss: 0.8509
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8205 - loss: 0.5077 - val_accuracy: 0.7432 - val_loss: 0.7738
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8611 - loss: 0.3998 - val_accuracy: 0.7390 - val_loss: 0.8298
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8587 - loss: 0.4075 - val_accuracy: 0.7358 - val_loss: 0.8240
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8502 - loss: 0.4403 - val_accuracy: 0.7366 - val_loss: 0.8308
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8376 - loss: 0.4494 - val_accuracy: 0.7372 - val_loss: 0.8165
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8370 - loss: 0.4669 - val_accuracy: 0.7298 - val_loss: 0.8410
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8304 - loss: 0.4514 - val_accuracy: 0.7439 - val_loss: 0.8040
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8462 - loss: 0.4241 - val_accuracy: 0.7453 - val_loss: 0.7996
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8783 - loss: 0.3485 - val_accuracy: 0.7360 - val_loss: 0.8622
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8733 - loss: 0.3563 - val_accuracy: 0.7373 - val_loss: 0.8779
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8730 - loss: 0.3625 - val_accuracy: 0.7330 - val_loss: 0.8432
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8745 - loss: 0.3545 - val_accuracy: 0.7425 - val_loss: 0.8586
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8585 - loss: 0.4020 - val_accuracy: 0.7408 - val_loss: 0.8466
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8632 - loss: 0.3910 - val_accuracy: 0.7349 - val_loss: 0.8546
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8602 - loss: 0.3892 - val_accuracy: 0.7348 - val_loss: 0.8476
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9027 - loss: 0.2892 - val_accuracy: 0.7420 - val_loss: 0.8888
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8926 - loss: 0.3033 - val_accuracy: 0.7375 - val_loss: 0.9055
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8835 - loss: 0.3257 - val_accuracy: 0.7466 - val_loss: 0.8913
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8909 - loss: 0.3117 - val_accuracy: 0.7381 - val_loss: 0.8934
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8783 - loss: 0.3412 - val_accuracy: 0.7435 - val_loss: 0.8802
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8674 - loss: 0.3655 - val_accuracy: 0.7401 - val_loss: 0.8713
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8895 - loss: 0.3305 - val_accuracy: 0.7425 - val_loss: 0.8766
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9154 - loss: 0.2463 - val_accuracy: 0.7323 - val_loss: 0.9437
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9019 - loss: 0.2629 - val_accuracy: 0.7429 - val_loss: 0.9048
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9065 - loss: 0.2756 - val_accuracy: 0.7355 - val_loss: 0.9688
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9020 - loss: 0.2781 - val_accuracy: 0.7301 - val_loss: 0.9180
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8871 - loss: 0.3117 - val_accuracy: 0.7383 - val_loss: 0.9107
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9019 - loss: 0.2806 - val_accuracy: 0.7447 - val_loss: 0.9089
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9029 - loss: 0.2900 - val_accuracy: 0.7421 - val_loss: 0.9178
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9244 - loss: 0.2184 - val_accuracy: 0.7421 - val_loss: 0.9670
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9312 - loss: 0.1929 - val_accuracy: 0.7419 - val_loss: 0.9896
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9215 - loss: 0.2210 - val_accuracy: 0.7359 - val_loss: 0.9886
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9219 - loss: 0.2319 - val_accuracy: 0.7392 - val_loss: 1.0114
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9197 - loss: 0.2208 - val_accuracy: 0.7368 - val_loss: 1.0029
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9074 - loss: 0.2618 - val_accuracy: 0.7472 - val_loss: 0.9631
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9048 - loss: 0.2753 - val_accuracy: 0.7400 - val_loss: 0.9967
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9230 - loss: 0.2103 - val_accuracy: 0.7405 - val_loss: 1.0238
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9407 - loss: 0.1807 - val_accuracy: 0.7327 - val_loss: 1.0411
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9189 - loss: 0.2309 - val_accuracy: 0.7377 - val_loss: 1.0312
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9213 - loss: 0.2231 - val_accuracy: 0.7358 - val_loss: 0.9810
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9236 - loss: 0.2130 - val_accuracy: 0.7433 - val_loss: 1.0265
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9223 - loss: 0.2285 - val_accuracy: 0.7426 - val_loss: 0.9885
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9195 - loss: 0.2161 - val_accuracy: 0.7420 - val_loss: 0.9722
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9417 - loss: 0.1657 - val_accuracy: 0.7461 - val_loss: 1.0166
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9439 - loss: 0.1628 - val_accuracy: 0.7391 - val_loss: 1.0699
#
# Training Model with Best Pool Dropout...
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.1608 - loss: 2.2221 - val_accuracy: 0.3411 - val_loss: 1.8265
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3507 - loss: 1.7755 - val_accuracy: 0.3647 - val_loss: 1.7454
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3926 - loss: 1.6703 - val_accuracy: 0.4436 - val_loss: 1.4964
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4271 - loss: 1.5295 - val_accuracy: 0.4803 - val_loss: 1.4193
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4736 - loss: 1.4414 - val_accuracy: 0.5068 - val_loss: 1.3598
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4884 - loss: 1.3654 - val_accuracy: 0.5088 - val_loss: 1.3484
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.5009 - loss: 1.3726 - val_accuracy: 0.5348 - val_loss: 1.2958
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5209 - loss: 1.3196 - val_accuracy: 0.5532 - val_loss: 1.2468
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5593 - loss: 1.2337 - val_accuracy: 0.5758 - val_loss: 1.1848
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5698 - loss: 1.2039 - val_accuracy: 0.5928 - val_loss: 1.1609
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5940 - loss: 1.1433 - val_accuracy: 0.6035 - val_loss: 1.1295
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5904 - loss: 1.1464 - val_accuracy: 0.6011 - val_loss: 1.1296
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6020 - loss: 1.1201 - val_accuracy: 0.6212 - val_loss: 1.0798
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6112 - loss: 1.1225 - val_accuracy: 0.6236 - val_loss: 1.0648
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6168 - loss: 1.0884 - val_accuracy: 0.6141 - val_loss: 1.0851
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6395 - loss: 1.0163 - val_accuracy: 0.6040 - val_loss: 1.1002
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6306 - loss: 1.0398 - val_accuracy: 0.6407 - val_loss: 1.0160
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6472 - loss: 0.9973 - val_accuracy: 0.6619 - val_loss: 0.9680
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6513 - loss: 0.9775 - val_accuracy: 0.6716 - val_loss: 0.9497
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6429 - loss: 0.9870 - val_accuracy: 0.6483 - val_loss: 1.0154
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6567 - loss: 0.9723 - val_accuracy: 0.6474 - val_loss: 0.9960
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6826 - loss: 0.8790 - val_accuracy: 0.6773 - val_loss: 0.9440
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6805 - loss: 0.9146 - val_accuracy: 0.6672 - val_loss: 0.9398
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6836 - loss: 0.8789 - val_accuracy: 0.6809 - val_loss: 0.9088
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6824 - loss: 0.8839 - val_accuracy: 0.6961 - val_loss: 0.8829
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7013 - loss: 0.8826 - val_accuracy: 0.7025 - val_loss: 0.8694
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7142 - loss: 0.8197 - val_accuracy: 0.6904 - val_loss: 0.9027
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6961 - loss: 0.8328 - val_accuracy: 0.6996 - val_loss: 0.8774
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7327 - loss: 0.7689 - val_accuracy: 0.7020 - val_loss: 0.8597
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7298 - loss: 0.7750 - val_accuracy: 0.7036 - val_loss: 0.8596
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7254 - loss: 0.7955 - val_accuracy: 0.7026 - val_loss: 0.8542
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7368 - loss: 0.7602 - val_accuracy: 0.7135 - val_loss: 0.8527
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7387 - loss: 0.7346 - val_accuracy: 0.7030 - val_loss: 0.8477
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7300 - loss: 0.7726 - val_accuracy: 0.7126 - val_loss: 0.8384
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7297 - loss: 0.7802 - val_accuracy: 0.7226 - val_loss: 0.8062
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7662 - loss: 0.6704 - val_accuracy: 0.7106 - val_loss: 0.8429
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7628 - loss: 0.6794 - val_accuracy: 0.7289 - val_loss: 0.7981
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7657 - loss: 0.6672 - val_accuracy: 0.7193 - val_loss: 0.8386
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7631 - loss: 0.6715 - val_accuracy: 0.7238 - val_loss: 0.8062
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7650 - loss: 0.6728 - val_accuracy: 0.7390 - val_loss: 0.7683
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7564 - loss: 0.6650 - val_accuracy: 0.7218 - val_loss: 0.8302
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7612 - loss: 0.6900 - val_accuracy: 0.7241 - val_loss: 0.7964
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8024 - loss: 0.5591 - val_accuracy: 0.7227 - val_loss: 0.8074
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8018 - loss: 0.5546 - val_accuracy: 0.7329 - val_loss: 0.7989
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7801 - loss: 0.6256 - val_accuracy: 0.7265 - val_loss: 0.8116
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7779 - loss: 0.6227 - val_accuracy: 0.7221 - val_loss: 0.8264
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7808 - loss: 0.6024 - val_accuracy: 0.7311 - val_loss: 0.7876
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7906 - loss: 0.5803 - val_accuracy: 0.7197 - val_loss: 0.8262
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7779 - loss: 0.6604 - val_accuracy: 0.7324 - val_loss: 0.7931
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8375 - loss: 0.4586 - val_accuracy: 0.7423 - val_loss: 0.7766
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8185 - loss: 0.5158 - val_accuracy: 0.7388 - val_loss: 0.7857
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8150 - loss: 0.5267 - val_accuracy: 0.7391 - val_loss: 0.7712
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8066 - loss: 0.5297 - val_accuracy: 0.7447 - val_loss: 0.7900
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8080 - loss: 0.5242 - val_accuracy: 0.7362 - val_loss: 0.7885
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8161 - loss: 0.5135 - val_accuracy: 0.7351 - val_loss: 0.8011
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8230 - loss: 0.4891 - val_accuracy: 0.7457 - val_loss: 0.7821
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8569 - loss: 0.4050 - val_accuracy: 0.7414 - val_loss: 0.7999
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8432 - loss: 0.4369 - val_accuracy: 0.7480 - val_loss: 0.7755
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8540 - loss: 0.4102 - val_accuracy: 0.7429 - val_loss: 0.8063
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8379 - loss: 0.4485 - val_accuracy: 0.7510 - val_loss: 0.7717
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8346 - loss: 0.4628 - val_accuracy: 0.7395 - val_loss: 0.8101
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8440 - loss: 0.4534 - val_accuracy: 0.7371 - val_loss: 0.8127
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8382 - loss: 0.4599 - val_accuracy: 0.7368 - val_loss: 0.8250
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8687 - loss: 0.3816 - val_accuracy: 0.7466 - val_loss: 0.8339
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8744 - loss: 0.3665 - val_accuracy: 0.7459 - val_loss: 0.8025
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8702 - loss: 0.3690 - val_accuracy: 0.7253 - val_loss: 0.8899
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8539 - loss: 0.4141 - val_accuracy: 0.7435 - val_loss: 0.8297
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8543 - loss: 0.4003 - val_accuracy: 0.7391 - val_loss: 0.8545
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8692 - loss: 0.3713 - val_accuracy: 0.7484 - val_loss: 0.8047
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8501 - loss: 0.4246 - val_accuracy: 0.7411 - val_loss: 0.8293
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8913 - loss: 0.3092 - val_accuracy: 0.7470 - val_loss: 0.8515
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8932 - loss: 0.2864 - val_accuracy: 0.7471 - val_loss: 0.8449
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8939 - loss: 0.2898 - val_accuracy: 0.7446 - val_loss: 0.8721
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8851 - loss: 0.3147 - val_accuracy: 0.7464 - val_loss: 0.8556
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8794 - loss: 0.3559 - val_accuracy: 0.7456 - val_loss: 0.8534
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8766 - loss: 0.3493 - val_accuracy: 0.7553 - val_loss: 0.8161
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8982 - loss: 0.2929 - val_accuracy: 0.7529 - val_loss: 0.8238
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9154 - loss: 0.2392 - val_accuracy: 0.7469 - val_loss: 0.8745
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9081 - loss: 0.2566 - val_accuracy: 0.7496 - val_loss: 0.8863
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9089 - loss: 0.2607 - val_accuracy: 0.7416 - val_loss: 0.9025
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9010 - loss: 0.2760 - val_accuracy: 0.7499 - val_loss: 0.8786
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9032 - loss: 0.2787 - val_accuracy: 0.7460 - val_loss: 0.8695
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8934 - loss: 0.2969 - val_accuracy: 0.7466 - val_loss: 0.8809
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9025 - loss: 0.2850 - val_accuracy: 0.7396 - val_loss: 0.9041
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9240 - loss: 0.2202 - val_accuracy: 0.7550 - val_loss: 0.9163
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9332 - loss: 0.1783 - val_accuracy: 0.7461 - val_loss: 0.9578
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9259 - loss: 0.2087 - val_accuracy: 0.7466 - val_loss: 0.9863
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9098 - loss: 0.2367 - val_accuracy: 0.7452 - val_loss: 0.9322
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9133 - loss: 0.2549 - val_accuracy: 0.7493 - val_loss: 0.9328
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9113 - loss: 0.2452 - val_accuracy: 0.7484 - val_loss: 0.9005
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9171 - loss: 0.2460 - val_accuracy: 0.7510 - val_loss: 0.9282
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9369 - loss: 0.1851 - val_accuracy: 0.7510 - val_loss: 0.9716
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9432 - loss: 0.1697 - val_accuracy: 0.7565 - val_loss: 0.9487
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9303 - loss: 0.1971 - val_accuracy: 0.7504 - val_loss: 0.9747
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9262 - loss: 0.2217 - val_accuracy: 0.7436 - val_loss: 0.9893
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9332 - loss: 0.1928 - val_accuracy: 0.7480 - val_loss: 0.9789
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9261 - loss: 0.2058 - val_accuracy: 0.7482 - val_loss: 0.9404
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9256 - loss: 0.2362 - val_accuracy: 0.7433 - val_loss: 1.0481
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9383 - loss: 0.1746 - val_accuracy: 0.7489 - val_loss: 1.0359
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9322 - loss: 0.1815 - val_accuracy: 0.7460 - val_loss: 1.0051
#
# Training Model with Best FC Dropout...
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.1866 - loss: 2.1990 - val_accuracy: 0.3419 - val_loss: 1.7643
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3686 - loss: 1.7074 - val_accuracy: 0.4136 - val_loss: 1.5852
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4416 - loss: 1.5311 - val_accuracy: 0.4498 - val_loss: 1.4987
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4671 - loss: 1.4599 - val_accuracy: 0.5036 - val_loss: 1.3807
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5043 - loss: 1.3641 - val_accuracy: 0.5297 - val_loss: 1.3032
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5318 - loss: 1.3034 - val_accuracy: 0.5379 - val_loss: 1.2890
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.5440 - loss: 1.3051 - val_accuracy: 0.5284 - val_loss: 1.3391
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5514 - loss: 1.2575 - val_accuracy: 0.5648 - val_loss: 1.2217
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5516 - loss: 1.2221 - val_accuracy: 0.5848 - val_loss: 1.1940
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5991 - loss: 1.1499 - val_accuracy: 0.5934 - val_loss: 1.1444
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6081 - loss: 1.1103 - val_accuracy: 0.6211 - val_loss: 1.0722
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6149 - loss: 1.0657 - val_accuracy: 0.6336 - val_loss: 1.0419
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6441 - loss: 1.0275 - val_accuracy: 0.6424 - val_loss: 1.0021
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6423 - loss: 1.0515 - val_accuracy: 0.6272 - val_loss: 1.0569
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6744 - loss: 0.9596 - val_accuracy: 0.6541 - val_loss: 0.9950
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6742 - loss: 0.9106 - val_accuracy: 0.6427 - val_loss: 1.0161
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6689 - loss: 0.9413 - val_accuracy: 0.6520 - val_loss: 1.0054
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6839 - loss: 0.8849 - val_accuracy: 0.6787 - val_loss: 0.9263
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6865 - loss: 0.8751 - val_accuracy: 0.6695 - val_loss: 0.9429
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7000 - loss: 0.8741 - val_accuracy: 0.6833 - val_loss: 0.9316
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6664 - loss: 0.9132 - val_accuracy: 0.6875 - val_loss: 0.8926
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7341 - loss: 0.7422 - val_accuracy: 0.6747 - val_loss: 0.9440
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7253 - loss: 0.7745 - val_accuracy: 0.6957 - val_loss: 0.8782
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7439 - loss: 0.7286 - val_accuracy: 0.6963 - val_loss: 0.8801
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7430 - loss: 0.7604 - val_accuracy: 0.6768 - val_loss: 0.9407
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7070 - loss: 0.8317 - val_accuracy: 0.6923 - val_loss: 0.8999
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7391 - loss: 0.7470 - val_accuracy: 0.6933 - val_loss: 0.8659
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7358 - loss: 0.7383 - val_accuracy: 0.6790 - val_loss: 0.9223
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7841 - loss: 0.6061 - val_accuracy: 0.7034 - val_loss: 0.8721
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7993 - loss: 0.5803 - val_accuracy: 0.7147 - val_loss: 0.8417
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7714 - loss: 0.6488 - val_accuracy: 0.7018 - val_loss: 0.8735
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7737 - loss: 0.6442 - val_accuracy: 0.6804 - val_loss: 0.9404
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7566 - loss: 0.6734 - val_accuracy: 0.7229 - val_loss: 0.8061
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7733 - loss: 0.6446 - val_accuracy: 0.7138 - val_loss: 0.8393
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7746 - loss: 0.6397 - val_accuracy: 0.7088 - val_loss: 0.8441
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8301 - loss: 0.5013 - val_accuracy: 0.7132 - val_loss: 0.8600
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8246 - loss: 0.5013 - val_accuracy: 0.7179 - val_loss: 0.8325
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8215 - loss: 0.5008 - val_accuracy: 0.7204 - val_loss: 0.8539
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8212 - loss: 0.5146 - val_accuracy: 0.7207 - val_loss: 0.8419
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8200 - loss: 0.5259 - val_accuracy: 0.7163 - val_loss: 0.8499
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8076 - loss: 0.5331 - val_accuracy: 0.7168 - val_loss: 0.8513
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8212 - loss: 0.5314 - val_accuracy: 0.7173 - val_loss: 0.8656
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8591 - loss: 0.3970 - val_accuracy: 0.7262 - val_loss: 0.8954
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8628 - loss: 0.3812 - val_accuracy: 0.7093 - val_loss: 0.9293
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8620 - loss: 0.3973 - val_accuracy: 0.7194 - val_loss: 0.9277
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8575 - loss: 0.4265 - val_accuracy: 0.7070 - val_loss: 0.8987
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8431 - loss: 0.4414 - val_accuracy: 0.7055 - val_loss: 0.9337
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8523 - loss: 0.4133 - val_accuracy: 0.7283 - val_loss: 0.8706
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8416 - loss: 0.4484 - val_accuracy: 0.7157 - val_loss: 0.9087
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9015 - loss: 0.2969 - val_accuracy: 0.7286 - val_loss: 0.9406
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8999 - loss: 0.2868 - val_accuracy: 0.7240 - val_loss: 0.9370
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9000 - loss: 0.2895 - val_accuracy: 0.7171 - val_loss: 0.9973
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8903 - loss: 0.3064 - val_accuracy: 0.7291 - val_loss: 0.9004
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8912 - loss: 0.3024 - val_accuracy: 0.7226 - val_loss: 0.9871
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8756 - loss: 0.3524 - val_accuracy: 0.7241 - val_loss: 0.9838
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8743 - loss: 0.3561 - val_accuracy: 0.7208 - val_loss: 0.9306
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9343 - loss: 0.1976 - val_accuracy: 0.7319 - val_loss: 1.0532
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9316 - loss: 0.2059 - val_accuracy: 0.7219 - val_loss: 1.0596
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9304 - loss: 0.2033 - val_accuracy: 0.7217 - val_loss: 1.1046
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9208 - loss: 0.2170 - val_accuracy: 0.7158 - val_loss: 1.0545
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9096 - loss: 0.2551 - val_accuracy: 0.7229 - val_loss: 1.0060
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9132 - loss: 0.2483 - val_accuracy: 0.7279 - val_loss: 1.0218
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9125 - loss: 0.2470 - val_accuracy: 0.7268 - val_loss: 1.0574
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9481 - loss: 0.1544 - val_accuracy: 0.7312 - val_loss: 1.0812
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9623 - loss: 0.1225 - val_accuracy: 0.7262 - val_loss: 1.1363
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9548 - loss: 0.1431 - val_accuracy: 0.7292 - val_loss: 1.1473
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9487 - loss: 0.1504 - val_accuracy: 0.7232 - val_loss: 1.1721
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9337 - loss: 0.1774 - val_accuracy: 0.7259 - val_loss: 1.1092
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9352 - loss: 0.1823 - val_accuracy: 0.7234 - val_loss: 1.1436
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9329 - loss: 0.1785 - val_accuracy: 0.7209 - val_loss: 1.2003
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9591 - loss: 0.1253 - val_accuracy: 0.7132 - val_loss: 1.2420
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9502 - loss: 0.1404 - val_accuracy: 0.7303 - val_loss: 1.1747
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9610 - loss: 0.1176 - val_accuracy: 0.7273 - val_loss: 1.2507
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9549 - loss: 0.1301 - val_accuracy: 0.7241 - val_loss: 1.2378
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9565 - loss: 0.1258 - val_accuracy: 0.7244 - val_loss: 1.2674
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9520 - loss: 0.1328 - val_accuracy: 0.7239 - val_loss: 1.2226
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9274 - loss: 0.1954 - val_accuracy: 0.7213 - val_loss: 1.2185
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9655 - loss: 0.0942 - val_accuracy: 0.7231 - val_loss: 1.2768
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9664 - loss: 0.1006 - val_accuracy: 0.7313 - val_loss: 1.3149
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9660 - loss: 0.0936 - val_accuracy: 0.7257 - val_loss: 1.2990
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9682 - loss: 0.0945 - val_accuracy: 0.7223 - val_loss: 1.3478
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9612 - loss: 0.1104 - val_accuracy: 0.7204 - val_loss: 1.3739
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9567 - loss: 0.1231 - val_accuracy: 0.7271 - val_loss: 1.3102
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9525 - loss: 0.1319 - val_accuracy: 0.7205 - val_loss: 1.2997
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9778 - loss: 0.0708 - val_accuracy: 0.7273 - val_loss: 1.3302
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9818 - loss: 0.0589 - val_accuracy: 0.7242 - val_loss: 1.4923
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9694 - loss: 0.0848 - val_accuracy: 0.7140 - val_loss: 1.5585
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9585 - loss: 0.1104 - val_accuracy: 0.7183 - val_loss: 1.4434
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9707 - loss: 0.0881 - val_accuracy: 0.7245 - val_loss: 1.4171
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9686 - loss: 0.0918 - val_accuracy: 0.7212 - val_loss: 1.5215
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9641 - loss: 0.1137 - val_accuracy: 0.7202 - val_loss: 1.4459
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9757 - loss: 0.0709 - val_accuracy: 0.7307 - val_loss: 1.4130
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9767 - loss: 0.0733 - val_accuracy: 0.6986 - val_loss: 1.5654
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9659 - loss: 0.0985 - val_accuracy: 0.7235 - val_loss: 1.5552
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9569 - loss: 0.1295 - val_accuracy: 0.7068 - val_loss: 1.5368
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9650 - loss: 0.1052 - val_accuracy: 0.7260 - val_loss: 1.4788
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9654 - loss: 0.1033 - val_accuracy: 0.7126 - val_loss: 1.4970
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9630 - loss: 0.1014 - val_accuracy: 0.7191 - val_loss: 1.4873
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9774 - loss: 0.0751 - val_accuracy: 0.7146 - val_loss: 1.5585
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9739 - loss: 0.0811 - val_accuracy: 0.7237 - val_loss: 1.5303

# %% [markdown]
# **Please note that I intentionally use validation set to estimate and compare dropout's ability in different layers.**

# %%
for name, history in histories.items():
    history.history['val_accuracy']

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

for name, history in histories.items():
    ax1.plot(history.history['val_accuracy'], label=name)
ax1.set_title("Validation Accuracy Comparison")
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Accuracy")
ax1.legend()

for name, history in histories.items():
    ax2.plot(history.history['val_loss'], label=name)
ax2.set_title("Validation Loss Comparison")
ax2.set_xlabel("Epochs")
ax2.set_ylabel("Loss")
ax2.legend()

fig.suptitle("Validation Accuracy and Loss Comparison", fontsize=16, y=1.00)
# Out:
# Text(0.5, 1.0, 'Validation Accuracy and Loss Comparison')

# %% [markdown]
# Using convolutional, max-pooling, and fully connected dropout individually enhances performance, though fully-connected dropout appears to be less beneficialㅡlower validation accuracy and overfitting presented, despite its common practice. **Interestingly, applying dropout in pooling layers yield best validation accuracy and effectively address overfitting.** Given simple CNN architecture, relatively lower dropout rate (0.3 for FC layers and 0.1 for pool & conv layers) seems to be most effective. Nevertheless, for deeper or wider architecture, the best dropout rate could be different.

# %% [markdown]
# # Problem 2
# ## CIFAR10 Image Classification
#
# ## 1. First Architecture
#
# Since CIFAR-10 has significant intra-class variation, I decided to use **a deeper network to capture non-linear patterns**. To achieve this, I incorporate eight convolutional layers, three pooling layers, and two fully connected layers. Additionally, **I reduce the kernel size from 5×5 to 3×3 to reduce computational costs and enhance model performance**. This is inspired by VGGNet, which demonstrates that stacking n convolutional layers with 3×3 filters and stride 1 achieves the same effective receptive field as a single convolutional layer with a (2n+1)×(2n+1) kernel. Despite using more layers, the total parameter count remains comparable, and deep, narrow networks generally outperform shallower ones with larger kernels. More layers introduce additional non-linearities, enhancing the model’s expressive power for capturing complex patterns. Nevertheless, I did not put too much layers to avoid vanishing gradient issues.
#
# Moreover, in the previous plot (validation loss), after around 30-40 epochs, the validation loss increases. This implies that the model begins to capture noise in the training data rather than learning generalisable patterns, an indication of overfitting.
#
# Given CIFAR-10 is considered to be independent and identically distributed (i.i.d.), **batch normalization** serves as an implicit form of regularisation, stabilising the training process by improving gradient flow—mitigating issues like vanishing or exploding gradients—and enabling the use of higher learning rates for faster convergence. In convolutional layers, batch normalization is applied per channel across all spatial locations, aligning with the assumption of translation invariance in convolutions. It is inserted after the convolutional layer and before the activation function. Moreover, the **ReLU** is used for the activation function in convolutional and fully connected layers, while softmax is applied in the output layer to produce probability distributions. Commonly used sigmoid and tanh activations are not used due to their susceptibility to the vanishing gradient problem. Lastly, I adopt **Learning Rate Scheduler**, which reduces the learning rate by 0.05 when validation loss stops improving with 2 patience. This helps the model converge more effectively by lowering the learning rate when training reaches a plateau. After trying out multiple patience and factor, 2 and 0.05 respectively produces higher validation accuracy.
#
#
# * Convolutional Filters Size : 3x3
# * Convolutional Stride : (1, 1)
# * Max-Pool Size : 2x2
# * Max-Pool Stride : (2, 2)
# * Activation Function : ReLU
# * Pooling Dropout = 0.1
# * Adam
# * 3x32x32-32C5-32C5-P2-64C5-64C5-P2-128C5-128C5-P2-1000N-10N
#
#
# **Optimisation Techniques:**
# * Batch normalization
# * Early stopping
# * Weight initialisation (he normal initialisation)
# * Learning Rate Scheduler (factor = 0.05, patience = 2)

# %%
def build_opt_model1():
    model_opt1 = Sequential()

    model_opt1.add(Conv2D(64, (3, 3), padding='same', input_shape=n_features, kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(Conv2D(64, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(Conv2D(64, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(MaxPooling2D(strides=(2, 2)))
    model_opt1.add(Dropout(0.1))

    model_opt1.add(Conv2D(128, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(Conv2D(128, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(Conv2D(128, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(MaxPooling2D(strides=(2, 2)))
    model_opt1.add(Dropout(0.1))

    model_opt1.add(Conv2D(256, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(Conv2D(256, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(MaxPooling2D(strides=(2, 2)))
    model_opt1.add(Dropout(0.1))

    model_opt1.add(Flatten())
    model_opt1.add(Dense(1000, use_bias=False, kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(Dropout(0.3))

    model_opt1.add(Dense(1000, kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=keras.regularizers.l2(0.0001)))
    model_opt1.add(BatchNormalization())
    model_opt1.add(Activation('relu'))
    model_opt1.add(Dropout(0.3))
    model_opt1.add(Dense(n_classes, activation='softmax'))

    model_opt1.compile(optimizer="Adam", loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy', TopKCategoricalAccuracy(k=5)])

    return model_opt1

# Build the model
model_opt1 = build_opt_model1()

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.05, patience=2, min_lr=1e-9)
early_stopping = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)

# Summary
model_opt1.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_59 (Conv2D)                   │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_58               │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_60 (Conv2D)                   │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_59               │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_61 (Conv2D)                   │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_60               │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_62 (Conv2D)                   │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_61               │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_63 (Conv2D)                   │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_62               │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_64 (Conv2D)                   │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_63               │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_65 (Conv2D)                   │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_64               │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_66 (Conv2D)                   │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_65               │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_7 (Activation)            │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1000)                │       4,096,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_66               │ (None, 1000)                │           4,000 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 1000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 1000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1000)                │       1,001,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_67               │ (None, 1000)                │           4,000 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_9 (Activation)            │ (None, 1000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 1000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │          10,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,449,282 (24.60 MB)
#  Trainable params: 6,443,106 (24.58 MB)
#  Non-trainable params: 6,176 (24.12 KB)

# %%
visualkeras.layered_view(model_opt1, legend=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=2300x209>

# %%
class TestErrorCallback(Callback):
    def __init__(self, test_data, test_labels):
        super().__init__()
        self.test_data = test_data
        self.test_labels = test_labels
        self.test_losses = []
        self.test_top1_errors = []
        self.test_top5_errors = []

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc, test_top5_acc = self.model.evaluate(self.test_data, self.test_labels, verbose=0)

        # Store values for later plotting
        self.test_losses.append(test_loss)
        self.test_top1_errors.append(1 - test_acc)
        self.test_top5_errors.append(1 - test_top5_acc)


test_error_callback_opt1 = TestErrorCallback(data_test, label_test)

# %%
# Start training timer
start = time.time()

# Train the model
history_opt1 = model_opt1.fit(data_train, label_train, epochs=n_epoch, batch_size=128,
                        validation_split=0.2, callbacks=[reduce_lr, early_stopping, test_error_callback_opt1])

# End training timer
end = time.time()

# Calculate and print execution time
time_es = (end - start) / 60
print('Minutes to run: ', time_es)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 113ms/step - accuracy: 0.4072 - loss: 2.3686 - top_k_categorical_accuracy: 0.8768 - val_accuracy: 0.5137 - val_loss: 2.0963 - val_top_k_categorical_accuracy: 0.9437 - learning_rate: 0.0010
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 53s 64ms/step - accuracy: 0.6671 - loss: 1.5680 - top_k_categorical_accuracy: 0.9709 - val_accuracy: 0.6482 - val_loss: 1.6142 - val_top_k_categorical_accuracy: 0.9628 - learning_rate: 0.0010
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 63ms/step - accuracy: 0.7507 - loss: 1.2901 - top_k_categorical_accuracy: 0.9860 - val_accuracy: 0.6991 - val_loss: 1.4491 - val_top_k_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 59ms/step - accuracy: 0.8040 - loss: 1.1033 - top_k_categorical_accuracy: 0.9909 - val_accuracy: 0.7411 - val_loss: 1.2963 - val_top_k_categorical_accuracy: 0.9822 - learning_rate: 0.0010
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.8327 - loss: 0.9918 - top_k_categorical_accuracy: 0.9930 - val_accuracy: 0.7809 - val_loss: 1.1550 - val_top_k_categorical_accuracy: 0.9850 - learning_rate: 0.0010
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 66ms/step - accuracy: 0.8633 - loss: 0.8887 - top_k_categorical_accuracy: 0.9958 - val_accuracy: 0.6377 - val_loss: 1.8281 - val_top_k_categorical_accuracy: 0.9702 - learning_rate: 0.0010
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 63ms/step - accuracy: 0.8797 - loss: 0.8276 - top_k_categorical_accuracy: 0.9972 - val_accuracy: 0.7784 - val_loss: 1.1448 - val_top_k_categorical_accuracy: 0.9872 - learning_rate: 0.0010
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 63ms/step - accuracy: 0.8868 - loss: 0.7990 - top_k_categorical_accuracy: 0.9977 - val_accuracy: 0.7340 - val_loss: 1.3264 - val_top_k_categorical_accuracy: 0.9825 - learning_rate: 0.0010
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 59ms/step - accuracy: 0.9036 - loss: 0.7504 - top_k_categorical_accuracy: 0.9985 - val_accuracy: 0.7634 - val_loss: 1.2809 - val_top_k_categorical_accuracy: 0.9845 - learning_rate: 0.0010
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9329 - loss: 0.6692 - top_k_categorical_accuracy: 0.9997 - val_accuracy: 0.8675 - val_loss: 0.8710 - val_top_k_categorical_accuracy: 0.9941 - learning_rate: 5.0000e-05
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 60ms/step - accuracy: 0.9630 - loss: 0.5892 - top_k_categorical_accuracy: 0.9996 - val_accuracy: 0.8750 - val_loss: 0.8530 - val_top_k_categorical_accuracy: 0.9940 - learning_rate: 5.0000e-05
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 63ms/step - accuracy: 0.9683 - loss: 0.5581 - top_k_categorical_accuracy: 0.9998 - val_accuracy: 0.8761 - val_loss: 0.8508 - val_top_k_categorical_accuracy: 0.9949 - learning_rate: 5.0000e-05
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 63ms/step - accuracy: 0.9764 - loss: 0.5298 - top_k_categorical_accuracy: 0.9998 - val_accuracy: 0.8781 - val_loss: 0.8463 - val_top_k_categorical_accuracy: 0.9940 - learning_rate: 5.0000e-05
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 61ms/step - accuracy: 0.9795 - loss: 0.5095 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.8803 - val_loss: 0.8404 - val_top_k_categorical_accuracy: 0.9942 - learning_rate: 5.0000e-05
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 64ms/step - accuracy: 0.9836 - loss: 0.4891 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8772 - val_loss: 0.8464 - val_top_k_categorical_accuracy: 0.9935 - learning_rate: 5.0000e-05
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 64ms/step - accuracy: 0.9861 - loss: 0.4712 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8790 - val_loss: 0.8412 - val_top_k_categorical_accuracy: 0.9934 - learning_rate: 5.0000e-05
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 64ms/step - accuracy: 0.9899 - loss: 0.4528 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8807 - val_loss: 0.8400 - val_top_k_categorical_accuracy: 0.9933 - learning_rate: 2.5000e-06
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 62ms/step - accuracy: 0.9888 - loss: 0.4535 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8807 - val_loss: 0.8392 - val_top_k_categorical_accuracy: 0.9933 - learning_rate: 2.5000e-06
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 62ms/step - accuracy: 0.9900 - loss: 0.4512 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8813 - val_loss: 0.8392 - val_top_k_categorical_accuracy: 0.9934 - learning_rate: 2.5000e-06
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 58ms/step - accuracy: 0.9898 - loss: 0.4500 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8807 - val_loss: 0.8393 - val_top_k_categorical_accuracy: 0.9933 - learning_rate: 2.5000e-06
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 61ms/step - accuracy: 0.9901 - loss: 0.4485 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8812 - val_loss: 0.8390 - val_top_k_categorical_accuracy: 0.9934 - learning_rate: 1.2500e-07
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 65ms/step - accuracy: 0.9908 - loss: 0.4477 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8808 - val_loss: 0.8394 - val_top_k_categorical_accuracy: 0.9932 - learning_rate: 1.2500e-07
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 65ms/step - accuracy: 0.9902 - loss: 0.4477 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8807 - val_loss: 0.8393 - val_top_k_categorical_accuracy: 0.9934 - learning_rate: 1.2500e-07
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 61ms/step - accuracy: 0.9899 - loss: 0.4496 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8811 - val_loss: 0.8394 - val_top_k_categorical_accuracy: 0.9934 - learning_rate: 6.2500e-09
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 62ms/step - accuracy: 0.9909 - loss: 0.4470 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8810 - val_loss: 0.8400 - val_top_k_categorical_accuracy: 0.9933 - learning_rate: 6.2500e-09
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 62ms/step - accuracy: 0.9915 - loss: 0.4464 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8809 - val_loss: 0.8395 - val_top_k_categorical_accuracy: 0.9933 - learning_rate: 1.0000e-09
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.9908 - loss: 0.4485 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8808 - val_loss: 0.8393 - val_top_k_categorical_accuracy: 0.9933 - learning_rate: 1.0000e-09
# Minutes to run:  10.625455137093862

# %%
test_loss_opt1 = test_error_callback_opt1.test_losses
test_top1_error_opt1 = test_error_callback_opt1.test_top1_errors
test_top5_error_opt1 = test_error_callback_opt1.test_top5_errors

# %%
epochs_total1 = len(test_error_callback_opt1.test_losses)
epochs1 = range(1, epochs_total1 + 1)


fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot test loss, top-1 error, and top-5 error
ax[0].plot(epochs1, test_loss_opt1, label='Test Loss', color='blue', linestyle='dotted')
ax[0].plot(epochs1, test_top1_error_opt1, label='Test Top-1 Error', color='red', linestyle='dotted')
ax[0].plot(epochs1, test_top5_error_opt1, label='Test Top-5 Error', color='green', linestyle='dotted')
ax[0].set_title('Test Loss & Error per Epoch')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Error / Loss')
ax[0].legend()

# Plot training loss, top-1 error, and top-5 error
ax[1].plot(epochs1, history_opt1.history['loss'], label='Training Loss', color='blue', linestyle='dotted')
ax[1].plot(epochs1, [1 - acc for acc in history_opt1.history['accuracy']],
           label='Training Top-1 Error', color='red', linestyle='dotted')
ax[1].plot(epochs1, [1 - acc for acc in history_opt1.history['top_k_categorical_accuracy']],
           label='Training Top-5 Error', color='green', linestyle='dotted')
ax[1].set_title('Training Loss & Error per Epoch')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Error / Loss')
ax[1].legend()
plt.show()

# %% [markdown]
# ### 2. Second Architecture
# This architecture utilises **Inception blocks** for multi-resolution feature extraction at all levels. Previous model uses relatively small size of kernel but put deeper layers, which produces decent performance. Nevertheless, the Inception approach applies multiple filters of different sizes in parallel to the same input, allowing the network to learn both fine and coarse features due to the diversity in receptive fields. Although this multi-branch strategy enriches feature representation, it introduces greater computational demands. To mitigate this, 1×1 convolutions are incorporated as bottleneck layers to reduce channel dimensionality while retaining critical information. For the 5×5 and 7×7 convolutional layer (c3, c4), a relatively smaller number of channels is used to reduce computational complexity. Moreover, instead of using fully-connected layer at the end of the architecture, I use averagepooling to reduce computational complexity. This pooling will spatially average across each feature map and promote sparser connections, eventually leading to more efficient computation. **Ultimately, the trainable parameters drastically decrease from 6,443,106 to 2,998,210**.
#
#
# Furthermore, **AdamW** is chosen as the optimizer, as it decouples weight decay from the gradient update step, potentially leading to better regularization compared to standard Adam. To mitigate vanishing gradient issues when x<0, **Leaky ReLU** is adopted as the activation function. Additionally, fully connected layers at the end of the architecture are replaced with average pooling layers to reduce the number of parameters and minimize overfitting.
#
# Notably, **auxiliary classifiers are not included in this architecture**. While they were originally introduced to prevent vanishing gradients in deep networks, subsequent research has shown that the contribution of auxiliary classifiers to accuracy improvement has been reported as minimal.
#
#
# * Convolutional Filters Size: 3×3, 5×5 7×7 (Inception blocks)
# * Convolutional Stride: (1,1)
# * Activation Function: LeakyReLU (α=0.3)
# * Kernel Initialization: He Normal Initialization
# * Regularization: L2 Regularization (0.0001)
# * Max-Pooling Size: 2×2
# * Max-Pooling Stride: (2,2)
# * Global Average Pooling: Final pooling before Dense layer
#
#
# **Optimisation Techniques:**
# * Layer normalization
# * Early stopping
# * Weight initialisation (he normal initialisation)
# * Exponential decay

# %%
class TestErrorCallback2(Callback):
    def __init__(self, test_data, test_labels):
        super().__init__()
        self.test_data = test_data
        self.test_labels = test_labels
        self.test_losses = []
        self.test_top1_errors = []
        self.test_top5_errors = []

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc, test_top5_acc = self.model.evaluate(self.test_data, self.test_labels, verbose=0)

        # Store values for later plotting
        self.test_losses.append(test_loss)
        self.test_top1_errors.append(1 - test_acc)
        self.test_top5_errors.append(1 - test_top5_acc)

test_error_callback_opt2 = TestErrorCallback2(data_test, label_test)

# %%
class Inception(tf.keras.Model):
    def __init__(self, c1, c2, c3, c4, c5):
        super().__init__()
        self.b1 = tf.keras.Sequential([
            tf.keras.layers.Conv2D(c1, (1, 1), kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LeakyReLU(negative_slope=0.3)])

        self.b2 = tf.keras.Sequential([
            tf.keras.layers.Conv2D(c2[0], (1, 1), kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LeakyReLU(negative_slope=0.3),

            tf.keras.layers.Conv2D(c2[1], (3, 3), padding='same', kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LeakyReLU(negative_slope=0.3)])

        self.b3 = tf.keras.Sequential([
            tf.keras.layers.Conv2D(c3[0], (1, 1), kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LeakyReLU(negative_slope=0.3),

            tf.keras.layers.Conv2D(c3[1], (5, 5), padding='same', kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LeakyReLU(negative_slope=0.3)])

        self.b4 = tf.keras.Sequential([
            tf.keras.layers.Conv2D(c4[0], (1, 1), kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LeakyReLU(negative_slope=0.3),

            tf.keras.layers.Conv2D(c4[1], (7, 7), padding='same', kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LeakyReLU(negative_slope=0.3)])

        self.b5 = tf.keras.Sequential([
            tf.keras.layers.MaxPooling2D((3, 3), strides=1, padding='same'),
            tf.keras.layers.Conv2D(c5, (1, 1), kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LeakyReLU(negative_slope=0.3)])

    def call(self, x):
        b1 = self.b1(x)
        b2 = self.b2(x)
        b3 = self.b3(x)
        b4 = self.b4(x)
        b5 = self.b5(x)
        return tf.keras.layers.Concatenate()([b1, b2, b3, b4, b5])

# %%
def build_opt_model2():
    model_opt2 = tf.keras.Sequential([
        # BLOCK 1
        tf.keras.layers.Conv2D(64, (3, 3), padding='same' , input_shape = n_features, kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(negative_slope=0.3),

        # BLOCK 2
        tf.keras.layers.Conv2D(64, (1,1)),
        tf.keras.layers.LeakyReLU(negative_slope=0.3),
        tf.keras.layers.Conv2D(64, (3, 3), padding='same', kernel_initializer=tf.keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(negative_slope=0.3),
        tf.keras.layers.MaxPooling2D((2, 2), padding='same'),
        tf.keras.layers.Dropout(0.1),

        # BLOCK 3
        Inception(64, (96, 128), (16, 32), (8, 16), 32),
        Inception(64, (96, 128), (16, 32), (8, 16), 32),
        Inception(128, (128, 192), (32, 96), (8, 16), 64),
        tf.keras.layers.MaxPooling2D((2, 2), padding='same'),
        tf.keras.layers.Dropout(0.2),

        Inception(192, (96, 208), (16, 48), (8, 16), 64),
        Inception(160, (112, 224), (24, 64), (8, 16), 64),
        Inception(160, (112, 224), (24, 64), (8, 16), 64),
        tf.keras.layers.MaxPooling2D((2, 2), padding='same'),
        tf.keras.layers.Dropout(0.2),

        Inception(256, (160, 320), (32, 128), (8, 16), 128),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(n_classes, activation='softmax')])

    model_opt2.compile(optimizer='AdamW', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy(k=5)])

    return model_opt2

# Build the model
model_opt2 = build_opt_model2()

# Summary
model_opt2.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 64)          │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception (Inception)                │ (None, 16, 16, 272)         │         145,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_1 (Inception)              │ (None, 16, 16, 272)         │         190,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_2 (Inception)              │ (None, 16, 16, 496)         │         405,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 496)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 496)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_3 (Inception)              │ (None, 8, 8, 528)           │         394,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_4 (Inception)              │ (None, 8, 8, 528)           │         468,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_5 (Inception)              │ (None, 8, 8, 528)           │         468,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 4, 4, 528)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 528)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_6 (Inception)              │ (None, 4, 4, 848)           │         883,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 848)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 848)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 10)                  │           8,490 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,007,442 (11.47 MB)
#  Trainable params: 2,998,210 (11.44 MB)
#  Non-trainable params: 9,232 (36.06 KB)

# %%
visualkeras.layered_view(model_opt2, legend=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=1217x209>

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.05, patience=2, min_lr=1e-9)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)

# Start training timer
import time
start = time.time()

# Train the model
history_inception = model_opt2.fit(data_train, label_train, epochs=n_epoch, batch_size=128, validation_split=0.2, callbacks=[reduce_lr, early_stopping, test_error_callback_opt2])

# End training timer
end = time.time()
time_es = (end - start) / 60
print('Minutes to run: ', time_es)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 220s 386ms/step - accuracy: 0.4686 - loss: 2.3854 - top_k_categorical_accuracy: 0.9052 - val_accuracy: 0.4991 - val_loss: 2.2664 - val_top_k_categorical_accuracy: 0.9499 - learning_rate: 0.0010
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 70s 134ms/step - accuracy: 0.7191 - loss: 1.6197 - top_k_categorical_accuracy: 0.9795 - val_accuracy: 0.6802 - val_loss: 1.6919 - val_top_k_categorical_accuracy: 0.9558 - learning_rate: 0.0010
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 141ms/step - accuracy: 0.7869 - loss: 1.3137 - top_k_categorical_accuracy: 0.9881 - val_accuracy: 0.7364 - val_loss: 1.4298 - val_top_k_categorical_accuracy: 0.9714 - learning_rate: 0.0010
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 146ms/step - accuracy: 0.8230 - loss: 1.1272 - top_k_categorical_accuracy: 0.9914 - val_accuracy: 0.7736 - val_loss: 1.2156 - val_top_k_categorical_accuracy: 0.9860 - learning_rate: 0.0010
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 141ms/step - accuracy: 0.8462 - loss: 0.9857 - top_k_categorical_accuracy: 0.9941 - val_accuracy: 0.7854 - val_loss: 1.1343 - val_top_k_categorical_accuracy: 0.9861 - learning_rate: 0.0010
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 135ms/step - accuracy: 0.8676 - loss: 0.8765 - top_k_categorical_accuracy: 0.9953 - val_accuracy: 0.7960 - val_loss: 1.0607 - val_top_k_categorical_accuracy: 0.9884 - learning_rate: 0.0010
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.8826 - loss: 0.7971 - top_k_categorical_accuracy: 0.9960 - val_accuracy: 0.7622 - val_loss: 1.1093 - val_top_k_categorical_accuracy: 0.9854 - learning_rate: 0.0010
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 83s 139ms/step - accuracy: 0.8950 - loss: 0.7243 - top_k_categorical_accuracy: 0.9979 - val_accuracy: 0.7425 - val_loss: 1.1780 - val_top_k_categorical_accuracy: 0.9792 - learning_rate: 0.0010
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 141ms/step - accuracy: 0.9312 - loss: 0.6108 - top_k_categorical_accuracy: 0.9990 - val_accuracy: 0.8764 - val_loss: 0.7762 - val_top_k_categorical_accuracy: 0.9952 - learning_rate: 5.0000e-05
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 135ms/step - accuracy: 0.9615 - loss: 0.5305 - top_k_categorical_accuracy: 0.9996 - val_accuracy: 0.8789 - val_loss: 0.7559 - val_top_k_categorical_accuracy: 0.9958 - learning_rate: 5.0000e-05
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 82s 135ms/step - accuracy: 0.9690 - loss: 0.5011 - top_k_categorical_accuracy: 0.9998 - val_accuracy: 0.8771 - val_loss: 0.7581 - val_top_k_categorical_accuracy: 0.9945 - learning_rate: 5.0000e-05
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 83s 138ms/step - accuracy: 0.9723 - loss: 0.4832 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.8829 - val_loss: 0.7340 - val_top_k_categorical_accuracy: 0.9964 - learning_rate: 5.0000e-05
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 83s 140ms/step - accuracy: 0.9792 - loss: 0.4623 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.8796 - val_loss: 0.7430 - val_top_k_categorical_accuracy: 0.9950 - learning_rate: 5.0000e-05
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 146ms/step - accuracy: 0.9818 - loss: 0.4466 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.8846 - val_loss: 0.7288 - val_top_k_categorical_accuracy: 0.9949 - learning_rate: 5.0000e-05
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.9860 - loss: 0.4290 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8775 - val_loss: 0.7460 - val_top_k_categorical_accuracy: 0.9949 - learning_rate: 5.0000e-05
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.9883 - loss: 0.4164 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8881 - val_loss: 0.7168 - val_top_k_categorical_accuracy: 0.9954 - learning_rate: 5.0000e-05
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 137ms/step - accuracy: 0.9907 - loss: 0.4025 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8805 - val_loss: 0.7414 - val_top_k_categorical_accuracy: 0.9948 - learning_rate: 5.0000e-05
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 143ms/step - accuracy: 0.9919 - loss: 0.3918 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8809 - val_loss: 0.7414 - val_top_k_categorical_accuracy: 0.9954 - learning_rate: 5.0000e-05
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 139ms/step - accuracy: 0.9936 - loss: 0.3814 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8877 - val_loss: 0.7211 - val_top_k_categorical_accuracy: 0.9961 - learning_rate: 2.5000e-06
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 133ms/step - accuracy: 0.9945 - loss: 0.3789 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8882 - val_loss: 0.7202 - val_top_k_categorical_accuracy: 0.9959 - learning_rate: 2.5000e-06
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 129ms/step - accuracy: 0.9955 - loss: 0.3766 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8883 - val_loss: 0.7204 - val_top_k_categorical_accuracy: 0.9961 - learning_rate: 1.2500e-07
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.9942 - loss: 0.3798 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8883 - val_loss: 0.7208 - val_top_k_categorical_accuracy: 0.9960 - learning_rate: 1.2500e-07
# Minutes to run:  27.630444991588593

# %%
test_loss_opt2 = test_error_callback_opt2.test_losses
test_top1_error_opt2 = test_error_callback_opt2.test_top1_errors
test_top5_error_opt2 = test_error_callback_opt2.test_top5_errors

# %%
epochs_total2 = len(test_error_callback_opt2.test_losses)
epochs2 = range(1, epochs_total2 + 1)


fig, ax = plt.subplots(1, 2, figsize=(14, 6))
# Plot test loss, top-1 error, and top-5 error
ax[0].plot(epochs2, test_loss_opt2, label='Test Loss', color='blue', linestyle='dotted')
ax[0].plot(epochs2, test_top1_error_opt2, label='Test Top-1 Error', color='red', linestyle='dotted')
ax[0].plot(epochs2, test_top5_error_opt2, label='Test Top-5 Error', color='green', linestyle='dotted')
ax[0].set_title('Test Loss & Error per Epoch')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Error / Loss')
ax[0].legend()

# Plot training loss, top-1 error, and top-5 error
ax[1].plot(epochs2, history_inception.history['loss'], label='Training Loss', color='blue', linestyle='dotted')
ax[1].plot(epochs2, [1 - acc for acc in history_inception.history['accuracy']],
           label='Training Top-1 Error', color='red', linestyle='dotted')
ax[1].plot(epochs2, [1 - acc for acc in history_inception.history['top_k_categorical_accuracy']],
           label='Training Top-5 Error', color='green', linestyle='dotted')
ax[1].set_title('Training Loss & Error per Epoch')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Error / Loss')
ax[1].legend()
fig.suptitle("Architecture 2", fontsize=18, y=1.02)
plt.show()

# %% [markdown]
# ### 3. Third Architecture

# %% [markdown]
# This architecture is inspired by ResNet-18 (with four residual block, two for each) without the use of bottleneck blocks (1x1, 3x3, 1x1).
#
# The initial Conv2D in ResNet is usually a 7x7 with stride 2 for larger images, followed by MaxPool. But the input of CIFAR-10 is smaller, I use relatively small size of kernel (3x3) and did not put max pooling (as the absence yield better validation accuracy)
#
# Here is the several other distinctions:
#
# 1. Downsampling is done via MaxPooling after residual blocks instead of using stride=2 in the first Conv2D of a residual block when increasing filters. This changes how the spatial dimensions are reduced.
#
# 2. Dropout is applied at MaxPooling, which is not present in the original ResNet.
#
# 3. L2 regularization is used instead of tuning weight decay.
#
# 4. Adam is used instead of SGD with momentum of 0.9 in original ResNet-18.
#
# 5. I manually designed learning rate to reduce error rate after 10-12 epochs (where little improvement is observed in architecture 1 and 2).
#
# The original ResNet starts with a learning rate of 0.1, reducing it by a factor of 10 at 32k and 48k iterations, and stopping at 64k iterations. Due to its unique architecture and optimiser, this model begins with a learning rate of 0.1 for the first epoch, then decreases to 0.001 until epoch 5. The learning rate schedule is illustrated in the graph below.

# %%
class TestErrorCallback3(Callback):
    def __init__(self, test_data, test_labels):
        super().__init__()
        self.test_data = test_data
        self.test_labels = test_labels
        self.test_losses = []
        self.test_top1_errors = []
        self.test_top5_errors = []

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc, test_top5_acc = self.model.evaluate(self.test_data, self.test_labels, verbose=0)

        # Store values for later plotting
        self.test_losses.append(test_loss)
        self.test_top1_errors.append(1 - test_acc)
        self.test_top5_errors.append(1 - test_top5_acc)

test_error_callback_opt3 = TestErrorCallback3(data_test, label_test)

# %%
def scheduler(epoch):
    if epoch <= 2:
        return 0.000001
    elif epoch <= 12:
        return 0.001
    elif epoch <= 17:
        return 5e-5
    elif epoch <= 20:
        return 1e-6
    elif epoch <= 25:
        return 5e-7
    return 1e-8

lrate = LearningRateScheduler(scheduler)

epochs = np.arange(1, 20)
learning_rates = [scheduler(epoch) for epoch in epochs]

# Learning rate schedule plot
plt.figure(figsize=(8, 5))
plt.plot(epochs, learning_rates, marker='o', linestyle='-', color='b')
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Learning Rate Schedule")
plt.yscale("log")
plt.show()

# %%
def residual_block(x, filters, kernel_size=3, stride=1):
    shortcut = x
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding='same',kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, kernel_size, strides=1, padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001))(x)
    x = layers.BatchNormalization()(x)

    if shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, (1, 1), strides=stride, padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001))(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def build_opt_model3():
    inputs = layers.Input(shape=n_features)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(), kernel_regularizer=regularizers.l2(0.0001))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.1)(x)

    x = residual_block(x, 128)
    x = residual_block(x, 128)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.1)(x)

    x = residual_block(x, 256)
    x = residual_block(x, 256)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.1)(x)

    x = residual_block(x, 512)
    x = residual_block(x, 512)
    x = AveragePooling2D(pool_size=(2, 2))(x)
    x = layers.Flatten()(x)

    outputs = layers.Dense(n_classes, activation='softmax')(x)

    model_opt3 = keras.Model(inputs, outputs)
    model_opt3.compile(optimizer='Adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=5)])

    return model_opt3

# Build the ResNet model
model_opt3 = build_opt_model3()

early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)

# Summary
model_opt3.summary()

start = time.time()

# Train the model
history_model_opt3 = model_opt3.fit(data_train, label_train, epochs=n_epoch, batch_size=128, validation_split=0.2, callbacks=[lrate, early_stopping, test_error_callback_opt3])
# End training timer
end = time.time()
time_es = (end - start) / 60
print('Minutes to run: ', time_es)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 32, 32, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 32, 32, 64)     │          1,792 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 32, 32, 64)     │            256 │ conv2d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ activation_17[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 32, 32, 64)     │            256 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_18             │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ activation_18[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 32, 32, 64)     │            256 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# │                           │                        │                │ activation_17[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_19             │ (None, 32, 32, 64)     │              0 │ add_8[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ activation_19[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 32, 32, 64)     │            256 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_20             │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ activation_20[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 32, 32, 64)     │            256 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# │                           │                        │                │ activation_19[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_21             │ (None, 32, 32, 64)     │              0 │ add_9[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 64)     │              0 │ activation_21[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 16, 16, 64)     │              0 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 16, 16, 128)    │         73,856 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 16, 16, 128)    │            512 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_22             │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 16, 16, 128)    │        147,584 │ activation_22[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 16, 16, 128)    │          8,320 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_26    │ (None, 16, 16, 128)    │            512 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_27    │ (None, 16, 16, 128)    │            512 │ conv2d_27[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# │                           │                        │                │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_23             │ (None, 16, 16, 128)    │              0 │ add_10[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 16, 16, 128)    │        147,584 │ activation_23[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_28    │ (None, 16, 16, 128)    │            512 │ conv2d_28[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_24             │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 16, 16, 128)    │        147,584 │ activation_24[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_29    │ (None, 16, 16, 128)    │            512 │ conv2d_29[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# │                           │                        │                │ activation_23[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_25             │ (None, 16, 16, 128)    │              0 │ add_11[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 8, 8, 128)      │              0 │ activation_25[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 8, 8, 128)      │              0 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 8, 8, 256)      │        295,168 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_30    │ (None, 8, 8, 256)      │          1,024 │ conv2d_30[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_26             │ (None, 8, 8, 256)      │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_31 (Conv2D)        │ (None, 8, 8, 256)      │        590,080 │ activation_26[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_32 (Conv2D)        │ (None, 8, 8, 256)      │         33,024 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_31    │ (None, 8, 8, 256)      │          1,024 │ conv2d_31[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_32    │ (None, 8, 8, 256)      │          1,024 │ conv2d_32[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 8, 8, 256)      │              0 │ batch_normalization_3… │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_27             │ (None, 8, 8, 256)      │              0 │ add_12[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_33 (Conv2D)        │ (None, 8, 8, 256)      │        590,080 │ activation_27[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_33    │ (None, 8, 8, 256)      │          1,024 │ conv2d_33[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_28             │ (None, 8, 8, 256)      │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 8, 8, 256)      │        590,080 │ activation_28[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_34    │ (None, 8, 8, 256)      │          1,024 │ conv2d_34[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 8, 8, 256)      │              0 │ batch_normalization_3… │
# │                           │                        │                │ activation_27[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_29             │ (None, 8, 8, 256)      │              0 │ add_13[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 4, 4, 256)      │              0 │ activation_29[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 4, 4, 256)      │              0 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 4, 4, 512)      │      1,180,160 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 4, 4, 512)      │          2,048 │ conv2d_35[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_30             │ (None, 4, 4, 512)      │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 4, 4, 512)      │      2,359,808 │ activation_30[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 4, 4, 512)      │        131,584 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 4, 4, 512)      │          2,048 │ conv2d_36[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 4, 4, 512)      │          2,048 │ conv2d_37[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 4, 4, 512)      │              0 │ batch_normalization_3… │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_31             │ (None, 4, 4, 512)      │              0 │ add_14[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 4, 4, 512)      │      2,359,808 │ activation_31[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_38    │ (None, 4, 4, 512)      │          2,048 │ conv2d_38[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_32             │ (None, 4, 4, 512)      │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 4, 4, 512)      │      2,359,808 │ activation_32[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_39    │ (None, 4, 4, 512)      │          2,048 │ conv2d_39[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 4, 4, 512)      │              0 │ batch_normalization_3… │
# │                           │                        │                │ activation_31[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_33             │ (None, 4, 4, 512)      │              0 │ add_15[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_1       │ (None, 2, 2, 512)      │              0 │ activation_33[0][0]    │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_1 (Flatten)       │ (None, 2048)           │              0 │ average_pooling2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 10)             │         20,490 │ flatten_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 11,203,722 (42.74 MB)
#  Trainable params: 11,194,122 (42.70 MB)
#  Non-trainable params: 9,600 (37.50 KB)
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 93s 200ms/step - accuracy: 0.1226 - loss: 3.5381 - top_k_categorical_accuracy: 0.5591 - val_accuracy: 0.1417 - val_loss: 3.2569 - val_top_k_categorical_accuracy: 0.6078 - learning_rate: 1.0000e-06
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 47s 141ms/step - accuracy: 0.1937 - loss: 3.1728 - top_k_categorical_accuracy: 0.6846 - val_accuracy: 0.2002 - val_loss: 3.1106 - val_top_k_categorical_accuracy: 0.7046 - learning_rate: 1.0000e-06
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.2427 - loss: 3.0428 - top_k_categorical_accuracy: 0.7525 - val_accuracy: 0.2343 - val_loss: 3.0418 - val_top_k_categorical_accuracy: 0.7393 - learning_rate: 1.0000e-06
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 134ms/step - accuracy: 0.4159 - loss: 2.8593 - top_k_categorical_accuracy: 0.8800 - val_accuracy: 0.5651 - val_loss: 2.2840 - val_top_k_categorical_accuracy: 0.9419 - learning_rate: 0.0010
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 82s 134ms/step - accuracy: 0.6527 - loss: 1.9087 - top_k_categorical_accuracy: 0.9723 - val_accuracy: 0.6559 - val_loss: 1.8996 - val_top_k_categorical_accuracy: 0.9671 - learning_rate: 0.0010
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 128ms/step - accuracy: 0.7430 - loss: 1.6113 - top_k_categorical_accuracy: 0.9836 - val_accuracy: 0.7237 - val_loss: 1.6284 - val_top_k_categorical_accuracy: 0.9833 - learning_rate: 0.0010
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 135ms/step - accuracy: 0.7882 - loss: 1.4214 - top_k_categorical_accuracy: 0.9896 - val_accuracy: 0.7508 - val_loss: 1.5277 - val_top_k_categorical_accuracy: 0.9806 - learning_rate: 0.0010
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 82s 133ms/step - accuracy: 0.8223 - loss: 1.2798 - top_k_categorical_accuracy: 0.9930 - val_accuracy: 0.7235 - val_loss: 1.6266 - val_top_k_categorical_accuracy: 0.9765 - learning_rate: 0.0010
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 140ms/step - accuracy: 0.8539 - loss: 1.1394 - top_k_categorical_accuracy: 0.9955 - val_accuracy: 0.7175 - val_loss: 1.7212 - val_top_k_categorical_accuracy: 0.9759 - learning_rate: 0.0010
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 133ms/step - accuracy: 0.8687 - loss: 1.0428 - top_k_categorical_accuracy: 0.9964 - val_accuracy: 0.7532 - val_loss: 1.4365 - val_top_k_categorical_accuracy: 0.9847 - learning_rate: 0.0010
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 128ms/step - accuracy: 0.8874 - loss: 0.9495 - top_k_categorical_accuracy: 0.9972 - val_accuracy: 0.7660 - val_loss: 1.3686 - val_top_k_categorical_accuracy: 0.9847 - learning_rate: 0.0010
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 134ms/step - accuracy: 0.8984 - loss: 0.8774 - top_k_categorical_accuracy: 0.9985 - val_accuracy: 0.7164 - val_loss: 1.6692 - val_top_k_categorical_accuracy: 0.9786 - learning_rate: 0.0010
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 140ms/step - accuracy: 0.9110 - loss: 0.8096 - top_k_categorical_accuracy: 0.9984 - val_accuracy: 0.7116 - val_loss: 1.9463 - val_top_k_categorical_accuracy: 0.9702 - learning_rate: 0.0010
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 135ms/step - accuracy: 0.9481 - loss: 0.6957 - top_k_categorical_accuracy: 0.9997 - val_accuracy: 0.8671 - val_loss: 0.9330 - val_top_k_categorical_accuracy: 0.9951 - learning_rate: 5.0000e-05
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 129ms/step - accuracy: 0.9746 - loss: 0.6143 - top_k_categorical_accuracy: 0.9998 - val_accuracy: 0.8738 - val_loss: 0.9330 - val_top_k_categorical_accuracy: 0.9950 - learning_rate: 5.0000e-05
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 135ms/step - accuracy: 0.9831 - loss: 0.5821 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.8788 - val_loss: 0.9388 - val_top_k_categorical_accuracy: 0.9954 - learning_rate: 5.0000e-05
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.9878 - loss: 0.5607 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8732 - val_loss: 0.9795 - val_top_k_categorical_accuracy: 0.9956 - learning_rate: 5.0000e-05
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 140ms/step - accuracy: 0.9900 - loss: 0.5434 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8778 - val_loss: 0.9866 - val_top_k_categorical_accuracy: 0.9947 - learning_rate: 5.0000e-05
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 135ms/step - accuracy: 0.9946 - loss: 0.5282 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8783 - val_loss: 0.9919 - val_top_k_categorical_accuracy: 0.9950 - learning_rate: 1.0000e-06
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 131ms/step - accuracy: 0.9947 - loss: 0.5262 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.8781 - val_loss: 0.9941 - val_top_k_categorical_accuracy: 0.9952 - learning_rate: 1.0000e-06
# Minutes to run:  22.240851946671803

# %%
test_loss_opt3 = test_error_callback_opt3.test_losses
test_top1_error_opt3 = test_error_callback_opt3.test_top1_errors
test_top5_error_opt3 = test_error_callback_opt3.test_top5_errors

# %%
epochs_total3 = len(test_error_callback_opt3.test_losses)
epochs3 = range(1, epochs_total3 + 1)

fig, ax = plt.subplots(1, 2, figsize=(14, 6))
# Plot test loss, top-1 error, and top-5 error
ax[0].plot(epochs3, test_loss_opt3, label='Test Loss', color='blue', linestyle='dotted')
ax[0].plot(epochs3, test_top1_error_opt3, label='Test Top-1 Error', color='red', linestyle='dotted')
ax[0].plot(epochs3, test_top5_error_opt3, label='Test Top-5 Error', color='green', linestyle='dotted')
ax[0].set_title('Test Loss & Error per Epoch')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Error / Loss')
ax[0].legend()

# Plot training loss, top-1 error, and top-5 error
ax[1].plot(epochs3, history_model_opt3.history['loss'], label='Training Loss', color='blue', linestyle='dotted')
ax[1].plot(epochs3, [1 - acc for acc in history_model_opt3.history['accuracy']],
           label='Training Top-1 Error', color='red', linestyle='dotted')
ax[1].plot(epochs3, [1 - acc for acc in history_model_opt3.history['top_k_categorical_accuracy']],
           label='Training Top-5 Error', color='green', linestyle='dotted')
ax[1].set_title('Training Loss & Error per Epoch')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Error / Loss')
ax[1].legend()
plt.show()

# %% [markdown]
# # Reference
#
# Choi, D. et al. (2019) “On empirical comparisons of optimizers for deep learning,” arXiv [cs.LG]. Available at: http://arxiv.org/abs/1910.05446.
